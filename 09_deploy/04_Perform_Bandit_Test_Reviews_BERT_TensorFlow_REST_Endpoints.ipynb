# %% [markdown]
# # Multi-Armed Bandits and Reinforcement Learning with Amazon SageMaker
#
# We demonstrate how you can manage your own contextual multi-armed bandit workflow on SageMaker using the built-in [AWS Reinforcement Learning Container](https://github.com/aws/sagemaker-rl-container) container to train and deploy contextual bandit models. We show how to train these models that interact with a live environment (using a simulated client application) and continuously update the model with efficient exploration.
#
# ### Why Contextual Bandits?
#
# Wherever we look to personalize content for a user (content layout, ads, search, product recommendations, etc.), contextual bandits come in handy. Traditional personalization methods collect a training dataset, build a model and deploy it for generating recommendations. However, the training algorithm does not inform us on how to collect this dataset, especially in a production system where generating poor recommendations lead to loss of revenue. Contextual bandit algorithms help us collect this data in a strategic manner by trading off between exploiting known information and exploring recommendations which may yield higher benefits. The collected data is used to update the personalization model in an online manner. Therefore, contextual bandits help us train a personalization model while minimizing the impact of poor recommendations.

# %% [markdown]
# ![](img/multi_armed_bandit_maximize_reward.png)

# %% [markdown]
# To implement the exploration-exploitation strategy, we need an iterative training and deployment system that: (1) recommends an action using the contextual bandit model based on user context, (2) captures the implicit feedback over time and (3) continuously trains the model with incremental interaction data. In this notebook, we show how to setup the infrastructure needed for such an iterative learning system. While the example demonstrates a bandits application, these continual learning systems are useful more generally in dynamic scenarios where models need to be continually updated to capture the recent trends in the data (e.g. tracking fraud behaviors based on detection mechanisms or tracking user interests over time).
#
# In a typical supervised learning setup, the model is trained with a SageMaker training job and it is hosted behind a SageMaker hosting endpoint. The client application calls the endpoint for inference and receives a response. In bandits, the client application also sends the reward (a score assigned to each recommendation generated by the model) back for subsequent model training. These rewards will be part of the dataset for the subsequent model training.

# %% [markdown]
# # Relevant Links
#
# In-Practice
# * [AWS Blog Post on Contextual Multi-Armed Bandits](https://aws.amazon.com/blogs/machine-learning/power-contextual-bandits-using-continual-learning-with-amazon-sagemaker-rl/)
# * [Multi-Armed Bandits at StitchFix](https://multithreaded.stitchfix.com/blog/2020/08/05/bandits/)
# * [Introduction to Contextual Bandits](https://getstream.io/blog/introduction-contextual-bandits/)
# * [Vowpal Wabbit Contextual Bandit Algorithms](https://github.com/VowpalWabbit/vowpal_wabbit/wiki/Contextual-Bandit-algorithms)
#
# Theory
# * [Learning to Interact](https://hunch.net/~jl/interact.pdf)
# * [Contextual Bandit Bake-Off](https://arxiv.org/pdf/1802.04064.pdf)
# * [Doubly-Robust Policy Evaluation and Learning](https://arxiv.org/pdf/1103.4601.pdf)
#
# Code
# * [AWS Open Source Reinforcement Learning Containers](https://github.com/aws/sagemaker-rl-container)
# * [AWS Open Source Bandit Experiment Manager](./common/sagemaker_rl/orchestrator/workflow/manager)
# * [Vowpal Wabbit Reinforcement Learning Framework](https://github.com/VowpalWabbit/)

# %% [markdown]
# # AWS Open Source Bandit `ExperimentManager` Library

# %% [markdown]
# ![](img/multi_armed_bandit_traffic_shift.png)

# %% [markdown]
# The bandit model is implemented by the open source [**Bandit Experiment Manager**](./common/sagemaker_rl/orchestrator/workflow/manager/) provided with this example.  This This implementation continuously updates a Vowpal Wabbit reinforcement learning model using Amazon SageMaker, DynamoDB, Kinesis, and S3.
#
# The client application, a recommender system with a review service in our case, pings the SageMaker hosting endpoint that is serving the bandit model.  The application sends the an `event` with the `context` (ie. user, product, and review text) to the bandit model and receives a recommended action from the bandit model.  In our case, the action is 1 of 2 BERT models that we are testing.  The bandit model stores this event data (given context and recommended action) in S3 using Amazon Kinesis.  _Note:  The context makes this a "contextual bandit" and differentiates this implementation from a regular multi-armed bandit._
#
# The client application uses the recommended BERT model to classify the review text as star rating 1 through 5 and  compares the predicted star rating to the user-selected star rating.  If the BERT model correctly predicts the star rating of the review text (ie. matches the user-selected star rating), then the bandit model is rewarded with `reward=1`.  If the BERT model incorrectly classifies the star rating of the review text, the bandit model is not rewarded (`reward=0`).
#
# The client application stores the rewards data in S3 using Amazon Kinesis.  Periodically (ie. every 100 rewards), we incrementally train an updated bandit model with the latest the reward and event data.  This updated bandit model is evaluated against the current model using a holdout dataset of rewards and events.  If the bandit model accuracy is above a given threshold relative to the existing model, it is automatically deployed in a blue/green manner with no downtime.  SageMaker RL supports offline evaluation by performing counterfactual analysis (CFA).  By default, we apply [**doubly robust (DR) estimation**](https://arxiv.org/pdf/1103.4601.pdf) method. The bandit model tries to minimize the cost (`1 - reward`), so a smaller evaluation score indicates better bandit model performance.
#
# Unlike traditional A/B tests, the bandit model will learn the best BERT model (action) for a given context over time and begin to shift traffic to the best model.  Depending on the aggressiveness of the bandit model algorithm selected, the bandit model will continuously explore the under-performing models, but start to favor and exploit the over-performing models.  And unlike A/B tests, multi-armed bandits allow you to add a new action (ie. BERT model) dynamically throughout the life of the experiment.  When the bandit model sees the new BERT model, it will start sending traffic and exploring the accuracy of the new BERT model - alongside the existing BERT models in the experiment.
#
# #### Local Mode
#
# To facilitate experimentation, we provide a `local_mode` that runs the contextual bandit example using the SageMaker Notebook instance itself instead of the SageMaker training and hosting cluster instances.  The workflow remains the same in `local_mode`, but runs much faster for small datasets.  Hence, it is a useful tool for experimenting and debugging.  However, it will not scale to production use cases with high throughput and large datasets.  In `local_mode`, the training, evaluation, and hosting is done in the local [SageMaker Vowpal Wabbit Docker Container](https://github.com/aws/sagemaker-rl-container).

# %%
import boto3
import sagemaker
import pandas as pd

sess   = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name='sagemaker', region_name=region)

# %%
# %store -r tensorflow_endpoint_name

# %%
try:
    tensorflow_endpoint_name
    print('[OK]')
except NameError:
    print('+++++++++++++++++++++++++++++++')
    print('[ERROR] Please run the notebooks in this section before you continue.')
    print('+++++++++++++++++++++++++++++++')
# Out:
# [OK]

# %%
print(tensorflow_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-37-202-tf-1601151660

# %%
# %store -r pytorch_endpoint_name

# %%
try:
    pytorch_endpoint_name
    print('[OK]')    
except NameError:
    print('+++++++++++++++++++++++++++++++')
    print('[ERROR] Please run the notebooks in this section before you continue.')
    print('+++++++++++++++++++++++++++++++')
# Out:
# [OK]

# %%
print(pytorch_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-37-202-pt-1601151634

# %% [markdown]
# # Configure the 2 BERT Models to Test with our Bandit Experiment

# %% [markdown]
# Now that the last trained bandit model is deployed as a SageMaker Endpoint, the client application will send the context to the endpoint and receive the recommended action.  The bandit model will recommend 1 of 2 actions in our example:  `1` or `2` which correspond to BERT model 1 and BERT model 2, respectively.  Let's configure these 2 BERT models below.

# %%
model_1_endpoint_name = tensorflow_endpoint_name

# %%
print(model_1_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-37-202-tf-1601151660

# %%
try:
    waiter = sm.get_waiter('endpoint_in_service')
    waiter.wait(EndpointName=model_1_endpoint_name)
except:
    print('###################')
    print('The endpoint is not running.')
    print('Please re-run the previous section to deploy the endpoint.')
    print('###################')

# %%
import json
from sagemaker.tensorflow.model import TensorFlowPredictor

model1 = TensorFlowPredictor(endpoint_name=model_1_endpoint_name,
                             sagemaker_session=sess,
                             model_name='saved_model',
                             model_version=0)

# %%
review = 'This is great!'

model1_predicted_class = model1.predict(review)[0]

print('[Predicted Star Rating: {}]'.format(model1_predicted_class), review)
# Out:
# [Predicted Star Rating: 5] This is great!

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">Model 1 SageMaker REST Endpoint</a></b>'.format(region, model_1_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/endpoints/tensorflow-training-2020-09-26-18-45-37-202-tf-1601151660">Model 1 SageMaker REST Endpoint</a></b>

# %%
model_2_endpoint_name = pytorch_endpoint_name

# %%
print(model_2_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-37-202-pt-1601151634

# %%
try:
    waiter = sm.get_waiter('endpoint_in_service')
    waiter.wait(EndpointName=model_2_endpoint_name)
except:
    print('###################')
    print('The endpoint is not running.')
    print('Please re-run the previous section to deploy the endpoint.')
    print('###################')

# %%
import json
from sagemaker.predictor import Predictor

model2 = Predictor(endpoint_name=model_2_endpoint_name,
                   sagemaker_session=sess)

# %%
review = 'This is great!'

model2_predicted_class = model2.predict(review).decode('utf-8')

print('[Predicted Star Rating: {}]'.format(model2_predicted_class), review)
# Out:
# [Predicted Star Rating: 5] This is great!

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">Model 2 SageMaker REST Endpoint</a></b>'.format(region, model_2_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-east-1#/endpoints/tensorflow-training-2020-09-26-18-45-37-202-pt-1601151634">Model 2 SageMaker REST Endpoint</a></b>

# %%
import yaml
import sys
import numpy as np
import time
import sagemaker

sys.path.append('common')
sys.path.append('common/sagemaker_rl')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Configuration
#
# The configuration for the bandits application can be specified in a `config.yaml` file as can be seen below. It configures the AWS resources needed. The DynamoDB tables are used to store metadata related to experiments, models and data joins. The `private_resource` specifices the SageMaker instance types and counts used for training, evaluation and hosting. The SageMaker container image is used for the bandits application. This config file also contains algorithm and SageMaker-specific setups.  Note that all the data generated and used for the bandits application will be stored in `s3://sagemaker-{REGION}-{AWS_ACCOUNT_ID}/{experiment_id}/`.
#
# Please make sure that the `num_arms` parameter in the config is equal to the number of actions in the client application (which is defined in the cell below).
#
# The Docker image is defined here:  https://github.com/aws/sagemaker-rl-container/blob/master/vw/docker/8.7.0/Dockerfile

# %%
# !pygmentize 'config.yaml'
# Out:
# resource:
#   shared_resource:
#     resources_cf_stack_name: "BanditsSharedResourceStack" # cloud formation stack
#     experiment_db:
#       table_name: "BanditsExperimentTable" # Dynamo table for status of an experiment
#     model_db:
#       table_name: "BanditsModelTable" # Dynamo table for status of all models trained
#     join_db:
#       table_name: "BanditsJoinTable" # Dynamo table for status of all joining job for reward ingestion
#     iam_role:
#       role_name: "BanditsIAMRole"
#   private_resource:
#     hosting_fleet:
#       instance_type: "ml.t2.medium"
#       instance_count: 1
#     training_fleet:
#       instance_type: "ml.c5.4xlarge"
#     evaluation_fleet:
#       instance_type: "ml.c5.4xlarge"
# image: "462105765813.dkr.ecr.{AWS_REGION}.amazonaws.com/sagemaker-rl-vw-container:vw-8.7.0-cpu" # Vowpal Wabbit container
# algor: # Vowpal Wabbit algorithm parameters
#   algorithms_parameters:
#     exploration_policy: "cover" # supports "egreedy", "bag", "cover"
#     epsilon: 0.10 # percent to explore with egreedy exploration policy
#     num_policies: 3 # number of nested policies to create when using bag or cover exploration policy
#     num_arms: 2
#     cfa_type: "dr" # supports "dr", "ips"
# local_mode: true # use local mode?
# soft_deployment: true # use the same endpoint with updated model using a blue-green deployment?

# %%
config_file = 'config.yaml'
with open(config_file, 'r') as yaml_file:
    config = yaml.load(yaml_file, Loader=yaml.FullLoader)

# %% [markdown]
# # Additional permissions for the IAM role
# IAM role requires additional permissions for [AWS CloudFormation](https://aws.amazon.com/cloudformation/), [Amazon DynamoDB](https://aws.amazon.com/dynamodb/), [Amazon Kinesis Data Firehose](https://aws.amazon.com/kinesis/data-firehose/) and [Amazon Athena](https://aws.amazon.com/athena/). Make sure the SageMaker role you are using has the permissions.

# %%
# from markdown_helper import *
# from IPython.display import Markdown

# display(Markdown(generate_help_for_experiment_manager_permissions(role)))

# %% [markdown]
# ### Client Application (Environment)
# The client application simulates a live environment that uses the bandit model to recommend a BERT model to classify review text submitted by the application user.
#
# The logic of reward generation resides in the client application.  We simulate the online learning loop with feedback.  The data consists of 2 actions - 1 for each BERT model under test.  If the bandit model selects the right class, then the model is rewarded with `reward=1`.  Otherwise, the bandit model receives `reward=0`.
#
# The workflow of the client application is as follows:
# - Our client application picks sample review text at random, which is sent to the bandit model (SageMaker endpoint) to recommend an action (BERT model) to classify the review text into star rating 1 through 5.
# - The bandit model returns an action, an action probability, and an `event_id` for this prediction event.
# - Since the client application uses the Amazon Customer Reviews Dataset, we know the true star rating for the review text
# - The client application compares the predicted and true star rating and assigns a reward to the bandit model using Amazon Kinesis, S3, and DynamoDB.  (The `event_id` is used to join the event and reward data.)
#
# `event_id` is a unique identifier for each interaction. It is used to join inference data `<state, action, action_probability>` with the reward data.
#
# In a later cell of this notebook, we illustrate how the client application interacts with the bandit model endpoint and receives the recommended action (BERT model).

# %% [markdown]
# ### Step-by-step bandits model development
#
# [**Bandit Experiment Manager**](./common/sagemaker_rl/orchestrator/workflow/manager/) is the top level class for all the Bandits/RL and continual learning workflows. Similar to the estimators in the [Sagemaker Python SDK](https://github.com/aws/sagemaker-python-sdk), `ExperimentManager` contains methods for training, deployment and evaluation. It keeps track of the job status and reflects current progress in the workflow.
#
# Start the application using the `ExperimentManager` class

# %%
import time
timestamp = int(time.time())

experiment_name = 'bandits-{}'.format(timestamp)

# %% [markdown]
# # `ExperimentManager` will create a AWS CloudFormation Stack of additional resources needed for the Bandit experiment.

# %%
from orchestrator.workflow.manager.experiment_manager import ExperimentManager

bandit_experiment_manager = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Creating a new CloudFormation stack for Shared Resources. You can always reuse this StackName in your other experiments
# INFO:orchestrator.resource_manager:[
#     {
#         "ParameterKey": "IAMRoleName",
#         "ParameterValue": "BanditsIAMRole",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbName",
#         "ParameterValue": "BanditsExperimentTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbName",
#         "ParameterValue": "BanditsModelTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbName",
#         "ParameterValue": "BanditsJoinTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     }
# ]
# INFO:orchestrator.resource_manager:Creating CloudFormation Stack for shared resource!
# INFO:orchestrator.resource_manager:Waiting for stack to get to CREATE_COMPLETE state....

# %%
try:
    bandit_experiment_manager.clean_resource(experiment_id=bandit_experiment_manager.experiment_id)
    bandit_experiment_manager.clean_table_records(experiment_id=bandit_experiment_manager.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# INFO:orchestrator:Deleting hosting endpoint 'bandits-1601152346'...
# WARNING:orchestrator.clients.ddb.experiment_db_client:Deleting experiment record...

# %%
bandit_experiment_manager = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Using Resources in CloudFormation stack named: BanditsSharedResourceStack for Shared Resources.

# %% [markdown]
# # Initialize the Bandit Model
# To start a new experiment, we need to initialize the first bandit model or "policy" in reinforcement learning terminology.
#
# If we have historical data in the format `(state, action, action probability, reward)`, we can perform a "warm start" and learn the bandit model offline.
#
# However, let's assume we are starting with no historical data and initialize a random bandit model using `initialize_first_model()`.

# %%
bandit_experiment_manager.initialize_first_model()
# Out:
# INFO:orchestrator:Next Model name would be bandits-1601152346-model-id-1601152394
# INFO:orchestrator:Start training job for model 'bandits-1601152346-model-id-1601152394''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpf4rnc5s1_algo-1-s967d_1 ...
# Attaching to tmpf4rnc5s1_algo-1-s967d_12mdone
# algo-1-s967d_1  | 2020-09-26 20:33:41,134 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-s967d_1  | 2020-09-26 20:33:41,146 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-s967d_1  | 2020-09-26 20:33:41,158 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-s967d_1  | 2020-09-26 20:33:41,167 sagemaker-containers INFO     Invoking user script
# algo-1-s967d_1  |
# algo-1-s967d_1  | Training Env:
# algo-1-s967d_1  |
# algo-1-s967d_1  | {
# algo-1-s967d_1  |     "additional_framework_parameters": {
# algo-1-s967d_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-s967d_1  |     },
# algo-1-s967d_1  |     "channel_input_dirs": {},
# algo-1-s967d_1  |     "current_host": "algo-1-s967d",
# algo-1-s967d_1  |     "framework_module": null,
# algo-1-s967d_1  |     "hosts": [
# algo-1-s967d_1  |         "algo-1-s967d"
# algo-1-s967d_1  |     ],
# algo-1-s967d_1  |     "hyperparameters": {
# algo-1-s967d_1  |         "exploration_policy": "cover",
# algo-1-s967d_1  |         "epsilon": 0.1,
# algo-1-s967d_1  |         "num_policies": 3,
# algo-1-s967d_1  |         "num_arms": 2,
# algo-1-s967d_1  |         "cfa_type": "dr"
# algo-1-s967d_1  |     },
# algo-1-s967d_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-s967d_1  |     "input_data_config": {},
# algo-1-s967d_1  |     "input_dir": "/opt/ml/input",
# algo-1-s967d_1  |     "is_master": true,
# algo-1-s967d_1  |     "job_name": "bandits-1601152346-model-id-1601152394",
# algo-1-s967d_1  |     "log_level": 20,
# algo-1-s967d_1  |     "master_hostname": "algo-1-s967d",
# algo-1-s967d_1  |     "model_dir": "/opt/ml/model",
# algo-1-s967d_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152394/source/sourcedir.tar.gz",
# algo-1-s967d_1  |     "module_name": "train-vw",
# algo-1-s967d_1  |     "network_interface_name": "eth0",
# algo-1-s967d_1  |     "num_cpus": 8,
# algo-1-s967d_1  |     "num_gpus": 0,
# algo-1-s967d_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-s967d_1  |     "output_dir": "/opt/ml/output",
# algo-1-s967d_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-s967d_1  |     "resource_config": {
# algo-1-s967d_1  |         "current_host": "algo-1-s967d",
# algo-1-s967d_1  |         "hosts": [
# algo-1-s967d_1  |             "algo-1-s967d"
# algo-1-s967d_1  |         ]
# algo-1-s967d_1  |     },
# algo-1-s967d_1  |     "user_entry_point": "train-vw.py"
# algo-1-s967d_1  | }
# algo-1-s967d_1  |
# algo-1-s967d_1  | Environment variables:
# algo-1-s967d_1  |
# algo-1-s967d_1  | SM_HOSTS=["algo-1-s967d"]
# algo-1-s967d_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-s967d_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-s967d_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-s967d_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-s967d_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-s967d","hosts":["algo-1-s967d"]}
# algo-1-s967d_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-s967d_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-s967d_1  | SM_CHANNELS=[]
# algo-1-s967d_1  | SM_CURRENT_HOST=algo-1-s967d
# algo-1-s967d_1  | SM_MODULE_NAME=train-vw
# algo-1-s967d_1  | SM_LOG_LEVEL=20
# algo-1-s967d_1  | SM_FRAMEWORK_MODULE=
# algo-1-s967d_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-s967d_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-s967d_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-s967d_1  | SM_NUM_CPUS=8
# algo-1-s967d_1  | SM_NUM_GPUS=0
# algo-1-s967d_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-s967d_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152394/source/sourcedir.tar.gz
# algo-1-s967d_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1-s967d","framework_module":null,"hosts":["algo-1-s967d"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601152346-model-id-1601152394","log_level":20,"master_hostname":"algo-1-s967d","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152394/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-s967d","hosts":["algo-1-s967d"]},"user_entry_point":"train-vw.py"}
# algo-1-s967d_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-s967d_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-s967d_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-s967d_1  | SM_HP_EPSILON=0.1
# algo-1-s967d_1  | SM_HP_NUM_POLICIES=3
# algo-1-s967d_1  | SM_HP_NUM_ARMS=2
# algo-1-s967d_1  | SM_HP_CFA_TYPE=dr
# algo-1-s967d_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-s967d_1  |
# algo-1-s967d_1  | Invoking script with the following command:
# algo-1-s967d_1  |
# algo-1-s967d_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-s967d_1  |
# algo-1-s967d_1  |
# algo-1-s967d_1  | INFO:root:channels []
# algo-1-s967d_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-s967d_1  | INFO:root:No training data found. Saving a randomly initialized model!
# algo-1-s967d_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-s967d_1  | INFO:VW CLI:successfully created VWModel
# algo-1-s967d_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-f', '/opt/ml/model/vw.model', '-p', '/dev/stdout']
# algo-1-s967d_1  | INFO:VW CLI:Started VW process!
# algo-1-s967d_1  | 2020-09-26 20:33:41,594 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpf4rnc5s1/algo-1-s967d Please remove it manually.
# tmpf4rnc5s1_algo-1-s967d_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# # ^^ Ignore `Failed to delete: /tmp/...` message above.  This is OK. ^^

# %% [markdown]
# # Check Experiment State:  TRAINED
# `training_state`: `TRAINED`
#
# Remember the `last_trained_model_id`.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'last_trained_model_id': 'bandits-1601152346-model-id-1601152394',
#   'next_model_to_train_id': None,
#   'training_state': <TrainingState.TRAINED: 'TRAINED'>},
#  'hosting_workflow_metadata': {'last_hosted_model_id': None,
#   'hosting_endpoint': None,
#   'hosting_state': None,
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Deploy the Bandit Model

# %% [markdown]
# Once training and evaluation is done, we can deploy the model.

# %%
import boto3
account_id = boto3.client('sts').get_caller_identity().get('Account')
region = boto3.session.Session().region_name

# !$(aws ecr get-login --region $region --registry-ids $account_id --no-include-email)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
print('Deploying newly-trained bandit model: {}'.format(bandit_experiment_manager.last_trained_model_id))
# Out:
# Deploying newly-trained bandit model: bandits-1601152346-model-id-1601152394

# %%
print('Deploying bandit model_id {}'.format(bandit_experiment_manager.last_trained_model_id))

bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
# Out:
# Deploying bandit model_id bandits-1601152346-model-id-1601152394
# INFO:orchestrator:Model 'bandits-1601152346-model-id-1601152394' is ready to deploy.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ff268d22be0>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ff268d221d0>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ff268d22390>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# Attaching to tmprftosged_algo-1-svi0d_1
# algo-1-svi0d_1  | 17:C 26 Sep 2020 20:33:57.151 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# algo-1-svi0d_1  | 17:C 26 Sep 2020 20:33:57.151 # Redis version=5.0.6, bits=64, commit=00000000, modified=0, pid=17, just started
# algo-1-svi0d_1  | 17:C 26 Sep 2020 20:33:57.151 # Configuration loaded
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.152 # You requested maxclients of 10000 requiring at least 10032 max file descriptors.
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.152 # Server can't set maximum open files to 10032 because of OS error: Operation not permitted.
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.152 # Current maximum open files is 4096. maxclients has been reduced to 4064 to compensate for low ulimit. If you need higher maxclients increase 'ulimit -n'.
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.153 # WARNING: The TCP backlog setting of 511 cannot be enforced because /proc/sys/net/core/somaxconn is set to the lower value of 128.
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.153 # Server initialized
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.153 # WARNING overcommit_memory is set to 0! Background save may fail under low memory condition. To fix this issue add 'vm.overcommit_memory = 1' to /etc/sysctl.conf and then reboot or run the command 'sysctl vm.overcommit_memory=1' for this to take effect.
# algo-1-svi0d_1  | 17:M 26 Sep 2020 20:33:57.153 # WARNING you have Transparent Huge Pages (THP) support enabled in your kernel. This will create latency and memory usage issues with Redis. To fix this issue run the command 'echo never > /sys/kernel/mm/transparent_hugepage/enabled' as root, and add it to your /etc/rc.local in order to retain the setting after a reboot. Redis must be restarted after THP is disabled.
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Redis server started successfully!
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Starting gunicorn...
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started server process with PID: 23
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started gunicorn.
# algo-1-svi0d_1  | [09/26/2020 20:34:00 WARNING 139633647494912] Loggers have already been setup.
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912 integration.py:348] worker started
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] loading entry points
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Number of server workers: 8
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [23] [INFO] Starting gunicorn 19.9.0
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [23] [INFO] Listening at: http://0.0.0.0:8080 (23)
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [23] [INFO] Using worker: sync
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [24] [INFO] Booting worker with pid: 24
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152394
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [27] [INFO] Booting worker with pid: 27
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152394
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [30] [INFO] Booting worker with pid: 30
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152394
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [2020-09-26 20:34:00 +0000] [33] [INFO] Booting worker with pid: 33
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152394
# algo-1-svi0d_1  | [09/26/2020 20:34:00 INFO 139633647494912] Started VW process!
# !

# %% [markdown]
# # Check Experiment State:  DEPLOYED
# `hosting_state`: `DEPLOYED`
#
# The `last_trained_model_id` and `last_hosted_model_id` are now the same as we just deployed the bandit model.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152394',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152394',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Initialize the Client Application

# %%
import csv
import numpy as np

class ClientApp():
    def __init__(self, data, num_events, bandit_model, bert_model_map):
        self.bandit_model = bandit_model
        self.bert_model_map = bert_model_map
        
        self.num_actions = 2

        df_reviews = pd.read_csv(data, 
                                 delimiter='\t', 
                                 quoting=csv.QUOTE_NONE,
                                 compression='gzip')
        df_scrubbed = df_reviews[['review_body', 'star_rating']].sample(n=num_events) # .query('star_rating == 1')
        df_scrubbed = df_scrubbed.reset_index()
        df_scrubbed.shape
        np_reviews = df_scrubbed.to_numpy()

        np_reviews = np.delete(np_reviews, 0, 1)
        
        # Last column is the label, the rest are the features (contexts)
        self.labels = np_reviews[:, -1]
        self.contexts = np_reviews[:, :-1].tolist()

        self.optimal_rewards = [1]
        self.rewards_tmp_buffer = []
        self.joined_data_tmp_buffer = []
        self.all_joined_data_buffer = []
        
        self.action_count = {}

    def increment_action_count(self, action):
        try:
            action_count = self.action_count[action]
        except:
            self.action_count[action] = 0
            action_count = 0
            
        self.action_count[action] = action_count + 1
                
    def choose_random_context(self):
        context_index = np.random.choice(len(self.contexts))
        context = self.contexts[context_index]
        return context_index, context    

    def clear_tmp_buffers(self):
        self.rewards_tmp_buffer.clear()
        self.joined_data_tmp_buffer.clear()

    def get_reward(self, 
                   context_index, 
                   action, 
                   event_id, 
                   bandit_model_id, 
                   action_prob, 
                   sample_prob, 
                   local_mode):

        context_to_predict = self.contexts[context_index][0]
    
        label = self.labels[context_index]
        
        bert_model = self.bert_model_map[action]

        self.increment_action_count(action)
        
        # TensorFlow returns [str]
        if (action == 1):
            bert_predicted_class = bert_model.predict(context_to_predict)[0]
            bert_predicted_class
            print('Predicted Class from Model 1: {}, Actual Class: {}'.format(bert_predicted_class, label))

        # PyTorch returns bytes
        if (action == 2):
            bert_predicted_class = bert_model.predict(context_to_predict)
            bert_predicted_class = bert_predicted_class.decode('utf-8')
            print('Predicted Class from Model 2: {}, Actual Class: {}'.format(bert_predicted_class, label))
            
       # Calculate difference between predicted and actual label
        if abs(int(bert_predicted_class) - int(label)) == 0:
            reward = 1
        else:
            reward = 0

        if local_mode:
            json_blob = {
                         "reward": reward,
                         "event_id": event_id,
                         "action": action,
                         "action_prob": action_prob,
                         "model_id": bandit_model_id,
                         "observation": [context_index],
                         "sample_prob": sample_prob
                        }
            
            self.joined_data_tmp_buffer.append(json_blob)            
        else:
            json_blob = {
                         "reward": reward, 
                         "event_id": event_id
                        }
            self.rewards_tmp_buffer.append(json_blob)
        
        return reward

# %%
bandit_model = bandit_experiment_manager.predictor

client_app = ClientApp(data='./data/amazon_reviews_us_Digital_Software_v1_00.tsv.gz',
                       num_events=100,
                       bandit_model=bandit_model,
                       bert_model_map={
                         1: model1,
                         2: model2
                       })

# %% [markdown]
# Make sure that `num_arms` specified in `config.yaml` is equal to the total unique actions in the simulation application.

# %%
print('Testing {} BERT models'.format(client_app.num_actions))

assert client_app.num_actions == bandit_experiment_manager.config["algor"]["algorithms_parameters"]["num_arms"]
# Out:
# Testing 2 BERT models

# %%
import time

context_index, context = client_app.choose_random_context()
action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

print('event ID: {}\nbert_model_id: {}\naction_probability: {}'.format(event_id, action, action_prob, bandit_model_id))
# Out:
# event ID: 212126205193512693165337842428041887746
# bert_model_id: 1
# action_probability: 1.0

# %% [markdown]
# # Generate Sample Events to Test the Bandit `ExperimentManager`
# Thsi will generated sample contexts to pass as events to the bandit using the Amazon Customer Reviews Dataset.  The bandit model will recommend an action (BERT model) based on the context and current state of the bandit.  We will assign a reward using the star ratings from Amazon Customer Reviews Dataset.

# %% [markdown]
# Client application generates a reward after receiving the recommended action and stores the tuple `<eventID, reward>` in S3. In this case, reward is 1 if predicted action is the true class, and 0 otherwise. SageMaker hosting endpoint saves all the inferences `<eventID, state, action, action probability>` to S3 using [**Kinesis Firehose**](https://aws.amazon.com/kinesis/data-firehose/). The `ExperimentManager` joins the reward with state, action and action probability using [**Amazon Athena**](https://aws.amazon.com/athena/).

# %%
local_mode = bandit_experiment_manager.local_mode

num_events = 100 

print('Generating {} sample events...'.format(num_events))

for i in range(num_events):
    context_index, context = client_app.choose_random_context()
    action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

    reward = client_app.get_reward(context_index=context_index, 
                                   action=action, 
                                   event_id=event_id, 
                                   bandit_model_id=bandit_model_id, 
                                   action_prob=action_prob, 
                                   sample_prob=sample_prob, 
                                   local_mode=local_mode)
# Out:
# Generating 100 sample events...
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 3
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1

# %% [markdown]
# # Create Bandit Model Training Data
#
# Join `Event` and `Reward` data and upload to S3 in the following format:
#
# ```
# {
#  'reward': 0, # 0 if the model is wrong, +1 if the model is correct
#  'event_id': 131181492351609994318271340276526219266, # unique event id
#  'action': 1, # suggested action (bert_model_id 1 or 2)
#  'action_prob': 0.9995, # probability that the suggested action is correct
#  'model_id': 'bandits-1597631299-model-id-1597631304', # unique bandit_model_id
#  'observation': [54], # feature (review_id)
#  'sample_prob': 0.43410828171830174
# }
# ```

# %%
if local_mode:
    print('Using local mode with memory buffers.')
    print()
    print(client_app.joined_data_tmp_buffer)
    bandit_experiment_manager.ingest_joined_data(client_app.joined_data_tmp_buffer)
else:
    print("Using production mode with Kinesis Firehose.  Waiting to flush to S3...")
    print()
    time.sleep(60) # Wait for firehose to flush data to S3
    rewards_s3_prefix = bandit_experiment_manager.ingest_rewards(client_app.rewards_tmp_buffer)
    bandit_experiment_manager.join(rewards_s3_prefix)
# Out:
# Using local mode with memory buffers.
#
# [{'reward': 1, 'event_id': 212133605896173150600207835687329857538, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [95], 'sample_prob': 0.4211127855953569}, {'reward': 1, 'event_id': 212271781396161277890257728207594848258, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [67], 'sample_prob': 0.6201144560414923}, {'reward': 0, 'event_id': 212432415703377323688989882312574500866, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [13], 'sample_prob': 0.9064936526259957}, {'reward': 0, 'event_id': 212575282302867920573564068889025970178, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [28], 'sample_prob': 0.9499156150091792}, {'reward': 1, 'event_id': 212685811927828320465654070183260717058, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [83], 'sample_prob': 0.885131836935845}, {'reward': 0, 'event_id': 212799506717881165218030933558311387138, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [25], 'sample_prob': 0.37961261717569905}, {'reward': 0, 'event_id': 212907160360542297313734325559259955202, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [58], 'sample_prob': 0.34918267269400405}, {'reward': 0, 'event_id': 213022389800103043366330375880628633602, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [19], 'sample_prob': 0.061000848192433565}, {'reward': 1, 'event_id': 213144576264614166970245008009970450434, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [40], 'sample_prob': 0.8199533398693134}, {'reward': 0, 'event_id': 213255634341418537005632265528659804162, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [50], 'sample_prob': 0.5482316114117933}, {'reward': 1, 'event_id': 213370603120324611128557633090431877122, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [71], 'sample_prob': 0.4537627396332137}, {'reward': 1, 'event_id': 213674250599131905200888521828171120642, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [95], 'sample_prob': 0.7047096173688527}, {'reward': 0, 'event_id': 213794264627426887676831846268700590082, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [31], 'sample_prob': 0.6031948597251131}, {'reward': 0, 'event_id': 213901727330216360396413601476617830402, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [97], 'sample_prob': 0.7815870899948049}, {'reward': 0, 'event_id': 213999204907684160381528442340474224642, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [53], 'sample_prob': 0.13216406719830032}, {'reward': 0, 'event_id': 214117587628112974154595208424760410114, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [26], 'sample_prob': 0.6521251593781939}, {'reward': 0, 'event_id': 214222382718670591594095696294175703042, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [7], 'sample_prob': 0.16704469332164373}, {'reward': 1, 'event_id': 214329905634863575154574022595495198722, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [86], 'sample_prob': 0.5696237822791524}, {'reward': 1, 'event_id': 214462908328121146125856925344936886274, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601152346-model-id-1601152394', 'observation': [87], 'sample_prob': 0.83628 ...
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-146478650644' for athena queries
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.8
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152462
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152462/train/local-joined-data-1601152462.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152462/eval/local-joined-data-1601152462.csv

# %% [markdown]
# # Check Experiment Status:  JOINED
# `joining_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152394',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': 'DEPLOYED',
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152394',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601152346-join-job-id-1601152462',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Review Bandit Model Training Data

# %%
print('Bandit model training data {}'.format(bandit_experiment_manager.last_joined_job_train_data))
# Out:
# Bandit model training data s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152462/train

# %%
from sagemaker.s3 import S3Downloader

bandit_model_train_data_s3_uri = S3Downloader.list(bandit_experiment_manager.last_joined_job_train_data)[0]
print(bandit_model_train_data_s3_uri)
# Out:
# s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152462/train/local-joined-data-1601152462.csv

# %%
from sagemaker.s3 import S3Downloader

bandit_model_train_data = S3Downloader.read_file(bandit_model_train_data_s3_uri)
print(bandit_model_train_data)
# Out:
# "reward","event_id","action","action_prob","model_id","observation","sample_prob"
# "1","212133605896173150600207835687329857538","1","1.0","bandits-1601152346-model-id-1601152394","[95]","0.4211127855953569"
# "1","212271781396161277890257728207594848258","1","1.0","bandits-1601152346-model-id-1601152394","[67]","0.6201144560414923"
# "0","212799506717881165218030933558311387138","1","1.0","bandits-1601152346-model-id-1601152394","[25]","0.37961261717569905"
# "0","212907160360542297313734325559259955202","1","1.0","bandits-1601152346-model-id-1601152394","[58]","0.34918267269400405"
# "0","213022389800103043366330375880628633602","1","1.0","bandits-1601152346-model-id-1601152394","[19]","0.061000848192433565"
# "0","213255634341418537005632265528659804162","1","1.0","bandits-1601152346-model-id-1601152394","[50]","0.5482316114117933"
# "1","213370603120324611128557633090431877122","1","1.0","bandits-1601152346-model-id-1601152394","[71]","0.4537627396332137"
# "1","213674250599131905200888521828171120642","1","1.0","bandits-1601152346-model-id-1601152394","[95]","0.7047096173688527"
# "0","213794264627426887676831846268700590082","1","1.0","bandits-1601152346-model-id-1601152394","[31]","0.6031948597251131"
# "0","213901727330216360396413601476617830402","1","1.0","bandits-1601152346-model-id-1601152394","[97]","0.7815870899948049"
# "0","213999204907684160381528442340474224642","1","1.0","bandits-1601152346-model-id-1601152394","[53]","0.13216406719830032"
# "0","214117587628112974154595208424760410114","1","1.0","bandits-1601152346-model-id-1601152394","[26]","0.6521251593781939"
# "0","214222382718670591594095696294175703042","1","1.0","bandits-1601152346-model-id-1601152394","[7]","0.16704469332164373"
# "1","214329905634863575154574022595495198722","1","1.0","bandits-1601152346-model-id-1601152394","[86]","0.5696237822791524"
# "0","214574778493591287370539009402811318274","1","1.0","bandits-1601152346-model-id-1601152394","[46]","0.5633308942393734"
# "0","214785110250307655763408846140405317634","1","1.0","bandits-1601152346-model-id-1601152394","[34]","0.06328517716304805"
# "1","214903363828831571285770842034358321154","1","1.0","bandits-1601152346-model-id-1601152394","[73]","0.20633097649968457"
# "1","215024394354451611773165491643770601474","1","1.0","bandits-1601152346-model-id-1601152394","[15]","0.24138443654427166"
# "0","215308631725724536225429338049117028354","1","1.0","bandits-1601152346-model-id-1601152394","[18]","0.7795761609694972"
# "1","215549522577004281515952380623795126274","1","1.0","bandits-1601152346-model-id-1601152394","[83]","0.5142104664694664"
# "0","215712147095662685637940264871694303234","1","1.0","bandits-1601152346-model-id-1601152394","[99]","0.07898039293976256"
# "0","215943899770678035679765268087140646914","1","1.0","bandits-1601152346-model-id-1601152394","[63]","0.6081314870090745"
# "0","216069870964512465691252251097295880194","1","1.0","bandits-1601152346-model-id-1601152394","[96]","0.7006837906636139"
# "1","216199256892151260495689515851710595074","1","1.0","bandits-1601152346-model-id-1601152394","[85]","0.6367775157506465"
# "1","216300031153461279019891624079340470274","1","1.0","bandits-1601152346-model-id-1601152394","[71]","0.1233109795607299"
# "0","216410786578684844565509274260139540482","1","1.0","bandits-1601152346-model-id-1601152394","[80]","0.5280422180161503"
# "0","216517924446008008801306895937860403202","1","1.0","bandits-1601152346-model-id-1601152394","[16]","0.1647623520452396"
# "0","216621685609044815091036280772417945602","1","1.0","bandits-1601152346-model-id-1601152394","[48]","0.45895400844335754"
# "1","216749983734012289043954969497396445186","1","1.0","bandits-1601152346-model-id-1601152394","[86]","0.18961614133125948"
# "0","216851677042007473036636579505848320002","1","1.0","bandits-1601152346-model-id-1601152394","[82]","0.6448617861816188"
# "1","217148754921579084310094211579225702402","1","1.0","bandits-1601152346-model-id-1601152394","[94]","0.18638077801660657"
# "1","217263913848075192667429803646478581762","1","1.0","bandits-1601152346-model-id-1601152394","[59]","0.41008197595422125"
# "0","217433505691345101195265664149370306562","1","1.0","bandits-1601152346-model-id-1601152394","[52]","0.4332466357994271"
# "0","217540554823126249455005181057866792962","1","1.0","bandits-1601152346-model-id-1601152394","[55]","0.36835642871021856"
# "1","217639648655109340432606930218310041602","1","1.0","bandits-1601152346-model-id-1601152394","[77]","0.6422687108925764"
# "1","217735131267445031241535658359191109634","1","1.0","bandits-1601152346-model-id-1601152394","[21]","0.037809629210971196"
# "0","217904114638426830219424307730850119682","1","1.0","bandits-1601152346-model-id-1601152394","[37]","0.46930933080866777"
# "1","218007856786704633085547162828553715714","1","1.0","bandits-1601152346-model-id-1601152394","[75]","0.7233956239920609"
# "0","218116638638399968306515357829549916162","1","1.0","bandits-1601152346-model-id-1601152394","[91]","0.027399651158260263"
# "1","218219186818268681207072768835229712386","1","1.0","bandits-1601152346-model-id-1601152394","[77]","0.1442562167871987"
# "1","218315266810949729569272459583802179586","1","1.0","bandits-1601152346-model-id-1601152394","[95]","0.16848571271849055"
# "0","218419004205537781581863983026172723202","1","1.0","bandits-1601152346-model-id-1601152394","[44]","0.6152899579413339"
# "1","218532515978535218383621005314698117122","1","1.0","bandits-1601152346-model-id-1601152394","[5]","0.23249335312217945"
# "1","218928776425631936608575074646745022466","1","1.0","bandits-1601152346-model-id-1601152394","[27]","0.3727560903264874"
# "1","219110748461576324083801211712008486914","1","1.0","bandits-1601152346-model-id-1601152394","[88]","0.6803628462166958"
# "1","219214778208084053729635038660557668354","1","1.0","bandits-1601152346-model-id-1601152394","[85]","0.04810996331677653"
# "0","219318412606060837196424273824794673154","1","1.0","bandits-1601152346-model-id-1601152394","[99]","0.16104466940063344"
# "0","219414040205933929109256305437410721794","1","1.0","bandits-1601152346-model-id-1601152394","[18]","0.6143041839034905"
# "1","219516586008957766584047005307770109954","1","1.0","bandits-1601152346-model-id-1601152394","[43]","0.7645197339400478"
# "0","219707389608177619102986785332485292034","1","1.0","bandits-1601152346-model-id-1601152394","[52]","0.6013815751580274"
# "0","219809172443996444212206459374602944514","1","1.0","bandits-1601152346-model-id-1601152394","[82]","0.5756386321786617"
# "0","220002813995997557677720930758926925826","1","1.0","bandits-1601152346-model-id-1601152394","[12]","0.5265807522798642"
# "0","220111335187038220970850845098712891394","1","1.0","bandits-1601152346-model-id-1601152394","[91]","0.5025940094061996"
# "1","220198934597203742478354522902841393154","1","1.0","bandits-1601152346-model-id-1601152394","[45]","0.36969514738516807"
# "1","220292281218278048720907236385127268354","1","1.0","bandits-1601152346-model-id-1601152394","[11]","0.5589913282234619"
# "0","220658896863806804661924816982469902338","1","1.0","bandits-1601152346-model-id-1601152394","[34]","0.6855862060145306"
# "0","220769500963239967961560192560128983042","1","1.0","bandits-1601152346-model-id-1601152394","[60]","0.15052050583191823"
# "1","220869472643263716988954441835430936578","1","1.0","bandits-1601152346-model-id-1601152394","[66]","0.21180451375400888"
# "1","220976997144019950834719520007629438978","1","1.0","bandits-1601152346-model-id-1601152394","[43]","0.6177269891791631"
# "0","221063110233856704743249942927249637378","1","1.0","bandits-1601152346-model-id-1601152394","[6]","0.6253574374254293"
# "1","221179837877970595534469887164719169538","1","1.0","bandits-1601152346-model-id-1601152394","[1]","0.012134228178525164"
# "1","221289379527744442549172626031698378754","1","1.0","bandits-1601152346-model-id-1601152394","[30]","0.7777200440748723"
# "1","221385771679385797112862435343435169794","1","1.0","bandits-1601152346-model-id-1601152394","[15]","0.13118550779367777"
# "1","221496043020536400503211881684391821314","1","1.0","bandits-1601152346-model-id-1601152394","[4]","0.3805718826532022"
# "1","221708924339522477922465478666307633154","1","1.0","bandits-1601152346-model-id-1601152394","[4]","0.2132819482171021"
# "1","221853099788257810450801330269931569154","1","1.0","bandits-1601152346-model-id-1601152394","[17]","0.720448233824582"
# "1","221984859391645532614958404887404216322","1","1.0","bandits-1601152346-model-id-1601152394","[95]","0.062178078443910434"
# "0","222302390021370201227000303045254971394","1","1.0","bandits-1601152346-model-id-1601152394","[44]","0.1391316117849608"
# "1","222417384945569905057157076476530655234","1","1.0","bandits-1601152346-model-id-1601152394","[94]","0.7989074197366244"
# "0","222514115401465195529568410220935380994","1","1.0","bandits-1601152346-model-id-1601152394","[35]","0.027857194428780097"
# "0","222620730362915765620903421794889891842","1","1.0","bandits-1601152346-model-id-1601152394","[91]","0.5218314286229367"
# "1","222722427632319075324638494809541181442","1","1.0","bandits-1601152346-model-id-1601152394","[90]","0.189512536756419"
# "1","222841266706963971260289799706981302274","1","1.0","bandits-1601152346-model-id-1601152394","[85]","0.43934523040397666"
# "0","222938169880253542830054558311392608258","1","1.0","bandits-1601152346-model-id-1601152394","[91]","0.4332996628795437"
# "1","223039931324468489086805611162448822274","1","1.0","bandits-1601152346-model-id-1601152394","[27]","0.20942517267270955"
# "1","223174040835156384331050203007182569474","1","1.0","bandits-1601152346-model-id-1601152394","[29]","0.4802296316925345"
# "1","223290879398697795090344868821490335746","1","1.0","bandits-1601152346-model-id-1601152394","[38]","0.04054462010779736"
# "1","223395752132854676510894107748669194242","1","1.0","bandits-1601152346-model-id-1601152394","[0]","0.7133216210018574"
# "1","223507144552504856739457086065524998146","1","1.0","bandits-1601152346-model-id-1601152394","[90]","0.02731872191461282"
# "1","223611974503453980458195988126859657218","1","1.0","bandits-1601152346-model-id-1601152394","[39]","0.24960702534645363"
# "1","223813679897835795749056676151252090882","1","1.0","bandits-1601152346-model-id-1601152394","[94]","0.41567290051947425"
# "0","224093604087941443650781930023942225922","1","1.0","bandits-1601152346-model-id-1601152394","[79]","0.49756577166916494"
# "1","224208201286765325873798476578281357314","1","1.0","bandits-1601152346-model-id-1601152394","[66]","0.24330329550023"
# "0","224297859836874593111436210589679091714","1","1.0","bandits-1601152346-model-id-1601152394","[58]","0.637486340644461"
# "1","224418289020741150332508525200508321794","1","1.0","bandits-1601152346-model-id-1601152394","[86]","0.36897117270919366"
# "1","224511903433004754788522304861346332674","1","1.0","bandits-1601152346-model-id-1601152394","[15]","0.3753595559700321"

# %% [markdown]
# # Train the Bandit Model

# %% [markdown]
# Now we can train a new model with newly collected experiences, and host the resulting model.

# %%
print('Trained bandit model id {}'.format(bandit_experiment_manager.last_trained_model_id))

bandit_experiment_manager.train_next_model(input_data_s3_prefix=bandit_experiment_manager.last_joined_job_train_data)
# Out:
# Trained bandit model id bandits-1601152346-model-id-1601152394
# INFO:orchestrator:Use last trained model bandits-1601152346-model-id-1601152394 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601152346-model-id-1601152471''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpllwbeanb_algo-1-d2q42_1 ...
# Attaching to tmpllwbeanb_algo-1-d2q42_12mdone
# algo-1-d2q42_1  | 2020-09-26 20:34:35,584 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-d2q42_1  | 2020-09-26 20:34:35,595 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-d2q42_1  | 2020-09-26 20:34:35,607 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-d2q42_1  | 2020-09-26 20:34:35,616 sagemaker-containers INFO     Invoking user script
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | Training Env:
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | {
# algo-1-d2q42_1  |     "additional_framework_parameters": {
# algo-1-d2q42_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-d2q42_1  |     },
# algo-1-d2q42_1  |     "channel_input_dirs": {
# algo-1-d2q42_1  |         "training": "/opt/ml/input/data/training",
# algo-1-d2q42_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-d2q42_1  |     },
# algo-1-d2q42_1  |     "current_host": "algo-1-d2q42",
# algo-1-d2q42_1  |     "framework_module": null,
# algo-1-d2q42_1  |     "hosts": [
# algo-1-d2q42_1  |         "algo-1-d2q42"
# algo-1-d2q42_1  |     ],
# algo-1-d2q42_1  |     "hyperparameters": {
# algo-1-d2q42_1  |         "exploration_policy": "cover",
# algo-1-d2q42_1  |         "epsilon": 0.1,
# algo-1-d2q42_1  |         "num_policies": 3,
# algo-1-d2q42_1  |         "num_arms": 2,
# algo-1-d2q42_1  |         "cfa_type": "dr"
# algo-1-d2q42_1  |     },
# algo-1-d2q42_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-d2q42_1  |     "input_data_config": {
# algo-1-d2q42_1  |         "training": {
# algo-1-d2q42_1  |             "TrainingInputMode": "File"
# algo-1-d2q42_1  |         },
# algo-1-d2q42_1  |         "pretrained_model": {
# algo-1-d2q42_1  |             "TrainingInputMode": "File",
# algo-1-d2q42_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-d2q42_1  |         }
# algo-1-d2q42_1  |     },
# algo-1-d2q42_1  |     "input_dir": "/opt/ml/input",
# algo-1-d2q42_1  |     "is_master": true,
# algo-1-d2q42_1  |     "job_name": "bandits-1601152346-model-id-1601152471",
# algo-1-d2q42_1  |     "log_level": 20,
# algo-1-d2q42_1  |     "master_hostname": "algo-1-d2q42",
# algo-1-d2q42_1  |     "model_dir": "/opt/ml/model",
# algo-1-d2q42_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152471/source/sourcedir.tar.gz",
# algo-1-d2q42_1  |     "module_name": "train-vw",
# algo-1-d2q42_1  |     "network_interface_name": "eth0",
# algo-1-d2q42_1  |     "num_cpus": 8,
# algo-1-d2q42_1  |     "num_gpus": 0,
# algo-1-d2q42_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-d2q42_1  |     "output_dir": "/opt/ml/output",
# algo-1-d2q42_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-d2q42_1  |     "resource_config": {
# algo-1-d2q42_1  |         "current_host": "algo-1-d2q42",
# algo-1-d2q42_1  |         "hosts": [
# algo-1-d2q42_1  |             "algo-1-d2q42"
# algo-1-d2q42_1  |         ]
# algo-1-d2q42_1  |     },
# algo-1-d2q42_1  |     "user_entry_point": "train-vw.py"
# algo-1-d2q42_1  | }
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | Environment variables:
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | SM_HOSTS=["algo-1-d2q42"]
# algo-1-d2q42_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-d2q42_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-d2q42_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-d2q42_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-d2q42_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-d2q42","hosts":["algo-1-d2q42"]}
# algo-1-d2q42_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-d2q42_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-d2q42_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-d2q42_1  | SM_CURRENT_HOST=algo-1-d2q42
# algo-1-d2q42_1  | SM_MODULE_NAME=train-vw
# algo-1-d2q42_1  | SM_LOG_LEVEL=20
# algo-1-d2q42_1  | SM_FRAMEWORK_MODULE=
# algo-1-d2q42_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-d2q42_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-d2q42_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-d2q42_1  | SM_NUM_CPUS=8
# algo-1-d2q42_1  | SM_NUM_GPUS=0
# algo-1-d2q42_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-d2q42_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152471/source/sourcedir.tar.gz
# algo-1-d2q42_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-d2q42","framework_module":null,"hosts":["algo-1-d2q42"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601152346-model-id-1601152471","log_level":20,"master_hostname":"algo-1-d2q42","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152471/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-d2q42","hosts":["algo-1-d2q42"]},"user_entry_point":"train-vw.py"}
# algo-1-d2q42_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-d2q42_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-d2q42_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-d2q42_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-d2q42_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-d2q42_1  | SM_HP_EPSILON=0.1
# algo-1-d2q42_1  | SM_HP_NUM_POLICIES=3
# algo-1-d2q42_1  | SM_HP_NUM_ARMS=2
# algo-1-d2q42_1  | SM_HP_CFA_TYPE=dr
# algo-1-d2q42_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | Invoking script with the following command:
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-d2q42_1  |
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-d2q42_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-d2q42_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-d2q42_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-d2q42_1  | INFO:VW CLI:successfully created VWModel
# algo-1-d2q42_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-d2q42_1  | INFO:VW CLI:Started VW process!
# algo-1-d2q42_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152462.csv')]
# algo-1-d2q42_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-d2q42_1  | predictions = /dev/stdout
# algo-1-d2q42_1  | Num weight bits = 18
# algo-1-d2q42_1  | learning rate = 0.5
# algo-1-d2q42_1  | initial_t = 0
# algo-1-d2q42_1  | power_t = 0.5
# algo-1-d2q42_1  | using no cache
# algo-1-d2q42_1  | Reading datafile =
# algo-1-d2q42_1  | num sources = 1
# algo-1-d2q42_1  | average  since         example        example  current  current  current
# algo-1-d2q42_1  | loss     last          counter         weight    label  predict features
# algo-1-d2q42_1  | 0.000000 0.000000            1            1.0        1 1:1.000000        2
# algo-1-d2q42_1  | 0.000000 0.000000            2            2.0        1 1:0.500000        2
# algo-1-d2q42_1  | 0.125000 0.250000            4            4.0        1 2:1.000000        2
# algo-1-d2q42_1  | 0.062500 0.000000            8            8.0        1 2:1.000000        2
# algo-1-d2q42_1  | 0.031250 0.000000           16           16.0        1 2:1.000000        2
# algo-1-d2q42_1  | 0.046875 0.062500           32           32.0        1 2:1.000000        2
# algo-1-d2q42_1  | 0.070313 0.093750           64           64.0        1 2:0.666667        2
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | finished run
# algo-1-d2q42_1  | number of examples = 86
# algo-1-d2q42_1  | weighted example sum = 86.000000
# algo-1-d2q42_1  | weighted label sum = 0.000000
# algo-1-d2q42_1  | average loss = 0.075581
# algo-1-d2q42_1  | total feature number = 171
# algo-1-d2q42_1  |
# algo-1-d2q42_1  | INFO:root:Model learned using 86 training experiences.
# algo-1-d2q42_1  | 2020-09-26 20:34:36,031 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpllwbeanb/algo-1-d2q42 Please remove it manually.
# tmpllwbeanb_algo-1-d2q42_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# # Ignore ^^ `Failed to delete` Error Above ^^

# %% [markdown]
# # Deploy the Bandit Model

# %%
print('Deploying bandit model id {}'.format(bandit_experiment_manager.last_hosted_model_id))

bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
# Out:
# Deploying bandit model id bandits-1601152346-model-id-1601152394
# INFO:orchestrator:Model 'bandits-1601152346-model-id-1601152471' is ready to deploy.
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Found new model! Trying to replace Model ID: bandits-1601152346-model-id-1601152394 with Model ID: bandits-1601152346-model-id-1601152471
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [23] [INFO] Handling signal: hup
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [23] [INFO] Hang up: Master
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [38] [INFO] Booting worker with pid: 38
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [39] [INFO] Booting worker with pid: 39
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/cn3P1np5/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152471
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [40] [INFO] Booting worker with pid: 40
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [27] [INFO] Worker exiting (pid: 27)
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [30] [INFO] Worker exiting (pid: 30)
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [24] [INFO] Worker exiting (pid: 24)
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [33] [INFO] Worker exiting (pid: 33)
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/cn3P1np5/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152471
# algo-1-svi0d_1  | [2020-09-26 20:34:46 +0000] [41] [INFO] Booting worker with pid: 41
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/cn3P1np5/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152471
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/cn3P1np5/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152471
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:34:46 INFO 139633647494912] Started VW process!

# %% [markdown]
# # Check Experiment Status:  DEPLOYED
# `deploying_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152471',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152471',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601152346-join-job-id-1601152462',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Continuously Train, Evaluate, and Deploy Bandit Models
# The above cells explained the individual steps in the training workflow. To train a model to convergence, we will continually train the model based on data collected with client application interactions. We demonstrate the continual training and evaluation loop in a single cell below.
#
# _**Train and Evaluate**_:
# After every training cycle, we evaluate if the newly trained model (`last_trained_model_id`) would perform better than the one currently deployed (`last_hosted_model_id`) using a holdout evaluation dataset.  Details of the join, train, and evaluation steps are tracked in the `BanditsJoinTable` and `BanditsModelTable` DynamoDB tables.  When you have multiple experiments, you can compare them in the `BanditsExperimentTable` DynamoDB table.
#
# _**Deploy**_: If the new bandit model is better than the current bandit model (based on offline evaluation), we will automatically deploy the new bandit model using a blue-green deployment to avoid downtime.

# %%
do_evaluation = True
total_loops = 5 # Increase for higher accuracy
retrain_batch_size = 100 # Model will be trained after every `batch_size` number of data instances
rewards_list = []
event_list = []

all_joined_train_data_s3_uri_list = []
all_joined_eval_data_s3_uri_list = []

local_mode = bandit_experiment_manager.local_mode

start_time = time.time()
for loop_no in range(total_loops):
    print(f"""
    ################################
    # Incremental Training Loop {loop_no+1}
    ################################
    """)
    
    # Generate experiences and log them
    for i in range(retrain_batch_size):
        context_index, context = client_app.choose_random_context()
        action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

        reward = client_app.get_reward(context_index=context_index, 
                                       action=action, 
                                       event_id=event_id, 
                                       bandit_model_id=bandit_model_id, 
                                       action_prob=action_prob, 
                                       sample_prob=sample_prob, 
                                       local_mode=local_mode)

        rewards_list.append(reward)
        
    # Publish rewards sum for this batch to CloudWatch for monitoring 
    bandit_experiment_manager.cw_logger.publish_rewards_for_simulation(
        bandit_experiment_manager.experiment_id,
        sum(rewards_list[-retrain_batch_size:])/retrain_batch_size
    )
    
    # Join the events and rewards data to use for the next bandit-model training job
    # Use 90% as the training dataset and 10% as the the holdout evaluation dataset
    if local_mode:        
        bandit_experiment_manager.ingest_joined_data(client_app.joined_data_tmp_buffer,
                                                     ratio=0.90)
    else:
        # Kinesis Firehose => S3 => Athena
        print('Waiting for firehose to flush data to s3...')
        time.sleep(60) 
        rewards_s3_prefix = bandit_experiment_manager.ingest_rewards(client_app.rewards_tmp_buffer)
        bandit_experiment_manager.join(rewards_s3_prefix, ratio=0.90)
            
    # Train 
    bandit_experiment_manager.train_next_model(
        input_data_s3_prefix=bandit_experiment_manager.last_joined_job_train_data)

    all_joined_train_data_s3_uri_list.append(bandit_experiment_manager.last_joined_job_train_data)

    # Evaluate and/or deploy the new bandit model
    if do_evaluation:
        bandit_experiment_manager.evaluate_model(
            input_data_s3_prefix=bandit_experiment_manager.last_joined_job_eval_data,
            evaluate_model_id=bandit_experiment_manager.last_trained_model_id)

        eval_score_last_trained_model = bandit_experiment_manager.get_eval_score(
            evaluate_model_id=bandit_experiment_manager.last_trained_model_id,
            eval_data_path=bandit_experiment_manager.last_joined_job_eval_data)

        bandit_experiment_manager.evaluate_model(
            input_data_s3_prefix=bandit_experiment_manager.last_joined_job_eval_data,
            evaluate_model_id=bandit_experiment_manager.last_hosted_model_id) 

        all_joined_eval_data_s3_uri_list.append(bandit_experiment_manager.last_joined_job_eval_data)
    
        # Eval score is a measure of `regret`, so a lower eval score is better
        eval_score_last_hosted_model = bandit_experiment_manager.get_eval_score(
            evaluate_model_id=bandit_experiment_manager.last_hosted_model_id, 
            eval_data_path=bandit_experiment_manager.last_joined_job_eval_data)
    
        print('New bandit model evaluation score {}'.format(eval_score_last_hosted_model))
        print('Current bandit model evaluation score {}'.format(eval_score_last_trained_model))

        if eval_score_last_trained_model <= eval_score_last_hosted_model:
            print('Deploying new bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
            bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
        else:
            print('Not deploying bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
    else:
        # Just deploy the new bandit model without evaluating against previous model
        print('Deploying new bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
        bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
    
    client_app.clear_tmp_buffers()
    
print(f'Total time taken to complete {total_loops} loops: {time.time() - start_time}')
# Out:
#     ################################
#     # Incremental Training Loop 1
#     ################################
#
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-146478650644' for athena queries
# Predicted Class from Model 2: 5, Actual Class: 5
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/train/local-joined-data-1601152506.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/eval/local-joined-data-1601152506.csv
# INFO:orchestrator:Use last trained model bandits-1601152346-model-id-1601152471 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601152346-model-id-1601152515''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpzcxdgmcd_algo-1-7y2n6_1 ...
# Attaching to tmpzcxdgmcd_algo-1-7y2n6_12mdone
# algo-1-7y2n6_1  | 2020-09-26 20:35:19,602 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-7y2n6_1  | 2020-09-26 20:35:19,614 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-7y2n6_1  | 2020-09-26 20:35:19,625 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-7y2n6_1  | 2020-09-26 20:35:19,635 sagemaker-containers INFO     Invoking user script
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | Training Env:
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | {
# algo-1-7y2n6_1  |     "additional_framework_parameters": {
# algo-1-7y2n6_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-7y2n6_1  |     },
# algo-1-7y2n6_1  |     "channel_input_dirs": {
# algo-1-7y2n6_1  |         "training": "/opt/ml/input/data/training",
# algo-1-7y2n6_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-7y2n6_1  |     },
# algo-1-7y2n6_1  |     "current_host": "algo-1-7y2n6",
# algo-1-7y2n6_1  |     "framework_module": null,
# algo-1-7y2n6_1  |     "hosts": [
# algo-1-7y2n6_1  |         "algo-1-7y2n6"
# algo-1-7y2n6_1  |     ],
# algo-1-7y2n6_1  |     "hyperparameters": {
# algo-1-7y2n6_1  |         "exploration_policy": "cover",
# algo-1-7y2n6_1  |         "epsilon": 0.1,
# algo-1-7y2n6_1  |         "num_policies": 3,
# algo-1-7y2n6_1  |         "num_arms": 2,
# algo-1-7y2n6_1  |         "cfa_type": "dr"
# algo-1-7y2n6_1  |     },
# algo-1-7y2n6_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-7y2n6_1  |     "input_data_config": {
# algo-1-7y2n6_1  |         "training": {
# algo-1-7y2n6_1  |             "TrainingInputMode": "File"
# algo-1-7y2n6_1  |         },
# algo-1-7y2n6_1  |         "pretrained_model": {
# algo-1-7y2n6_1  |             "TrainingInputMode": "File",
# algo-1-7y2n6_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-7y2n6_1  |         }
# algo-1-7y2n6_1  |     },
# algo-1-7y2n6_1  |     "input_dir": "/opt/ml/input",
# algo-1-7y2n6_1  |     "is_master": true,
# algo-1-7y2n6_1  |     "job_name": "bandits-1601152346-model-id-1601152515",
# algo-1-7y2n6_1  |     "log_level": 20,
# algo-1-7y2n6_1  |     "master_hostname": "algo-1-7y2n6",
# algo-1-7y2n6_1  |     "model_dir": "/opt/ml/model",
# algo-1-7y2n6_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152515/source/sourcedir.tar.gz",
# algo-1-7y2n6_1  |     "module_name": "train-vw",
# algo-1-7y2n6_1  |     "network_interface_name": "eth0",
# algo-1-7y2n6_1  |     "num_cpus": 8,
# algo-1-7y2n6_1  |     "num_gpus": 0,
# algo-1-7y2n6_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-7y2n6_1  |     "output_dir": "/opt/ml/output",
# algo-1-7y2n6_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-7y2n6_1  |     "resource_config": {
# algo-1-7y2n6_1  |         "current_host": "algo-1-7y2n6",
# algo-1-7y2n6_1  |         "hosts": [
# algo-1-7y2n6_1  |             "algo-1-7y2n6"
# algo-1-7y2n6_1  |         ]
# algo-1-7y2n6_1  |     },
# algo-1-7y2n6_1  |     "user_entry_point": "train-vw.py"
# algo-1-7y2n6_1  | }
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | Environment variables:
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | SM_HOSTS=["algo-1-7y2n6"]
# algo-1-7y2n6_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-7y2n6_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-7y2n6_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-7y2n6_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-7y2n6_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-7y2n6","hosts":["algo-1-7y2n6"]}
# algo-1-7y2n6_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-7y2n6_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-7y2n6_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-7y2n6_1  | SM_CURRENT_HOST=algo-1-7y2n6
# algo-1-7y2n6_1  | SM_MODULE_NAME=train-vw
# algo-1-7y2n6_1  | SM_LOG_LEVEL=20
# algo-1-7y2n6_1  | SM_FRAMEWORK_MODULE=
# algo-1-7y2n6_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-7y2n6_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-7y2n6_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-7y2n6_1  | SM_NUM_CPUS=8
# algo-1-7y2n6_1  | SM_NUM_GPUS=0
# algo-1-7y2n6_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-7y2n6_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152515/source/sourcedir.tar.gz
# algo-1-7y2n6_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-7y2n6","framework_module":null,"hosts":["algo-1-7y2n6"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601152346-model-id-1601152515","log_level":20,"master_hostname":"algo-1-7y2n6","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152515/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-7y2n6","hosts":["algo-1-7y2n6"]},"user_entry_point":"train-vw.py"}
# algo-1-7y2n6_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-7y2n6_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-7y2n6_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-7y2n6_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-7y2n6_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-7y2n6_1  | SM_HP_EPSILON=0.1
# algo-1-7y2n6_1  | SM_HP_NUM_POLICIES=3
# algo-1-7y2n6_1  | SM_HP_NUM_ARMS=2
# algo-1-7y2n6_1  | SM_HP_CFA_TYPE=dr
# algo-1-7y2n6_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | Invoking script with the following command:
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-7y2n6_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-7y2n6_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-7y2n6_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-7y2n6_1  | INFO:VW CLI:successfully created VWModel
# algo-1-7y2n6_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-7y2n6_1  | INFO:VW CLI:Started VW process!
# algo-1-7y2n6_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152506.csv')]
# algo-1-7y2n6_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-7y2n6_1  | predictions = /dev/stdout
# algo-1-7y2n6_1  | Num weight bits = 18
# algo-1-7y2n6_1  | learning rate = 0.5
# algo-1-7y2n6_1  | initial_t = 0
# algo-1-7y2n6_1  | power_t = 0.5
# algo-1-7y2n6_1  | using no cache
# algo-1-7y2n6_1  | Reading datafile =
# algo-1-7y2n6_1  | num sources = 1
# algo-1-7y2n6_1  | average  since         example        example  current  current  current
# algo-1-7y2n6_1  | loss     last          counter         weight    label  predict features
# algo-1-7y2n6_1  | 0.000000 0.000000            1            1.0        1 1:0.500000        2
# algo-1-7y2n6_1  | 0.000000 0.000000            2            2.0        1 2:1.000000        2
# algo-1-7y2n6_1  | 0.102062 0.204124            4            4.0        1 2:0.591752        2
# algo-1-7y2n6_1  | 0.051031 0.000000            8            8.0        1 2:1.000000        2
# algo-1-7y2n6_1  | 0.129682 0.208333           16           16.0        1 2:1.000000        2
# algo-1-7y2n6_1  | 0.137758 0.145833           32           32.0        1 2:0.666667        2
# algo-1-7y2n6_1  | 0.110546 0.083333           64           64.0        1 2:1.000000        2
# algo-1-7y2n6_1  | 0.217927 0.325307          128          128.0        1 1:0.666667        2
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | finished run
# algo-1-7y2n6_1  | number of examples = 188
# algo-1-7y2n6_1  | weighted example sum = 188.000000
# algo-1-7y2n6_1  | weighted label sum = 0.000000
# algo-1-7y2n6_1  | average loss = 0.296453
# algo-1-7y2n6_1  | total feature number = 375
# algo-1-7y2n6_1  |
# algo-1-7y2n6_1  | INFO:root:Model learned using 188 training experiences.
# algo-1-7y2n6_1  | 2020-09-26 20:35:20,092 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpzcxdgmcd/algo-1-7y2n6 Please remove it manually.
# tmpzcxdgmcd_algo-1-7y2n6_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152515' with evaluation job id 'bandits-1601152346-model-id-1601152515-eval-1601152530'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpv_pnbxx5/algo-1-c23yu Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152515' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152515'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/eval' is 0.475253.
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152471' with evaluation job id 'bandits-1601152346-model-id-1601152471-eval-1601152545'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpxym9dafs/algo-1-hemow Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152471' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152471'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152506/eval' is 0.412087.
# New bandit model evaluation score 0.412087
# Current bandit model evaluation score 0.475253
# Not deploying bandit model id bandits-1601152346-model-id-1601152515 in loop 0
#
#     ################################
#     # Incremental Training Loop 2
#     ################################
#
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 2
# Predicted Class from Model 2: 2, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 2: 2, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-146478650644' for athena queries
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/train/local-joined-data-1601152570.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/eval/local-joined-data-1601152570.csv
# INFO:orchestrator:Use last trained model bandits-1601152346-model-id-1601152515 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601152346-model-id-1601152579''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpzqv1iuhr_algo-1-ch608_1 ...
# Attaching to tmpzqv1iuhr_algo-1-ch608_12mdone
# algo-1-ch608_1  | 2020-09-26 20:36:23,423 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ch608_1  | 2020-09-26 20:36:23,435 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ch608_1  | 2020-09-26 20:36:23,446 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ch608_1  | 2020-09-26 20:36:23,455 sagemaker-containers INFO     Invoking user script
# algo-1-ch608_1  |
# algo-1-ch608_1  | Training Env:
# algo-1-ch608_1  |
# algo-1-ch608_1  | {
# algo-1-ch608_1  |     "additional_framework_parameters": {
# algo-1-ch608_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-ch608_1  |     },
# algo-1-ch608_1  |     "channel_input_dirs": {
# algo-1-ch608_1  |         "training": "/opt/ml/input/data/training",
# algo-1-ch608_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-ch608_1  |     },
# algo-1-ch608_1  |     "current_host": "algo-1-ch608",
# algo-1-ch608_1  |     "framework_module": null,
# algo-1-ch608_1  |     "hosts": [
# algo-1-ch608_1  |         "algo-1-ch608"
# algo-1-ch608_1  |     ],
# algo-1-ch608_1  |     "hyperparameters": {
# algo-1-ch608_1  |         "exploration_policy": "cover",
# algo-1-ch608_1  |         "epsilon": 0.1,
# algo-1-ch608_1  |         "num_policies": 3,
# algo-1-ch608_1  |         "num_arms": 2,
# algo-1-ch608_1  |         "cfa_type": "dr"
# algo-1-ch608_1  |     },
# algo-1-ch608_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ch608_1  |     "input_data_config": {
# algo-1-ch608_1  |         "training": {
# algo-1-ch608_1  |             "TrainingInputMode": "File"
# algo-1-ch608_1  |         },
# algo-1-ch608_1  |         "pretrained_model": {
# algo-1-ch608_1  |             "TrainingInputMode": "File",
# algo-1-ch608_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-ch608_1  |         }
# algo-1-ch608_1  |     },
# algo-1-ch608_1  |     "input_dir": "/opt/ml/input",
# algo-1-ch608_1  |     "is_master": true,
# algo-1-ch608_1  |     "job_name": "bandits-1601152346-model-id-1601152579",
# algo-1-ch608_1  |     "log_level": 20,
# algo-1-ch608_1  |     "master_hostname": "algo-1-ch608",
# algo-1-ch608_1  |     "model_dir": "/opt/ml/model",
# algo-1-ch608_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152579/source/sourcedir.tar.gz",
# algo-1-ch608_1  |     "module_name": "train-vw",
# algo-1-ch608_1  |     "network_interface_name": "eth0",
# algo-1-ch608_1  |     "num_cpus": 8,
# algo-1-ch608_1  |     "num_gpus": 0,
# algo-1-ch608_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ch608_1  |     "output_dir": "/opt/ml/output",
# algo-1-ch608_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ch608_1  |     "resource_config": {
# algo-1-ch608_1  |         "current_host": "algo-1-ch608",
# algo-1-ch608_1  |         "hosts": [
# algo-1-ch608_1  |             "algo-1-ch608"
# algo-1-ch608_1  |         ]
# algo-1-ch608_1  |     },
# algo-1-ch608_1  |     "user_entry_point": "train-vw.py"
# algo-1-ch608_1  | }
# algo-1-ch608_1  |
# algo-1-ch608_1  | Environment variables:
# algo-1-ch608_1  |
# algo-1-ch608_1  | SM_HOSTS=["algo-1-ch608"]
# algo-1-ch608_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ch608_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-ch608_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-ch608_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-ch608_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ch608","hosts":["algo-1-ch608"]}
# algo-1-ch608_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-ch608_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ch608_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-ch608_1  | SM_CURRENT_HOST=algo-1-ch608
# algo-1-ch608_1  | SM_MODULE_NAME=train-vw
# algo-1-ch608_1  | SM_LOG_LEVEL=20
# algo-1-ch608_1  | SM_FRAMEWORK_MODULE=
# algo-1-ch608_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ch608_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ch608_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ch608_1  | SM_NUM_CPUS=8
# algo-1-ch608_1  | SM_NUM_GPUS=0
# algo-1-ch608_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ch608_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152579/source/sourcedir.tar.gz
# algo-1-ch608_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-ch608","framework_module":null,"hosts":["algo-1-ch608"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601152346-model-id-1601152579","log_level":20,"master_hostname":"algo-1-ch608","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152579/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ch608","hosts":["algo-1-ch608"]},"user_entry_point":"train-vw.py"}
# algo-1-ch608_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-ch608_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ch608_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-ch608_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-ch608_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-ch608_1  | SM_HP_EPSILON=0.1
# algo-1-ch608_1  | SM_HP_NUM_POLICIES=3
# algo-1-ch608_1  | SM_HP_NUM_ARMS=2
# algo-1-ch608_1  | SM_HP_CFA_TYPE=dr
# algo-1-ch608_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-ch608_1  |
# algo-1-ch608_1  | Invoking script with the following command:
# algo-1-ch608_1  |
# algo-1-ch608_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-ch608_1  |
# algo-1-ch608_1  |
# algo-1-ch608_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-ch608_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-ch608_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-ch608_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-ch608_1  | INFO:VW CLI:successfully created VWModel
# algo-1-ch608_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-ch608_1  | INFO:VW CLI:Started VW process!
# algo-1-ch608_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152570.csv')]
# algo-1-ch608_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-ch608_1  | predictions = /dev/stdout
# algo-1-ch608_1  | Num weight bits = 18
# algo-1-ch608_1  | learning rate = 0.5
# algo-1-ch608_1  | initial_t = 0
# algo-1-ch608_1  | power_t = 0.5
# algo-1-ch608_1  | using no cache
# algo-1-ch608_1  | Reading datafile =
# algo-1-ch608_1  | num sources = 1
# algo-1-ch608_1  | average  since         example        example  current  current  current
# algo-1-ch608_1  | loss     last          counter         weight    label  predict features
# algo-1-ch608_1  | 0.117950 0.117950            1            1.0        2 1:0.500000        2
# algo-1-ch608_1  | 0.206645 0.295340            2            2.0        1 2:1.000000        2
# algo-1-ch608_1  | 0.496884 0.787123            4            4.0        2 2:1.000000        2
# algo-1-ch608_1  | 0.568221 0.639557            8            8.0        1 2:1.000000        2
# algo-1-ch608_1  | 0.708247 0.848273           16           16.0        1 2:0.666667        2
# algo-1-ch608_1  | 0.603802 0.499358           32           32.0        2 1:1.000000        2
# algo-1-ch608_1  | 0.401693 0.199584           64           64.0        1 1:1.000000        2
# algo-1-ch608_1  |
# algo-1-ch608_1  | finished run
# algo-1-ch608_1  | number of examples = 93
# algo-1-ch608_1  | weighted example sum = 93.000000
# algo-1-ch608_1  | weighted label sum = 0.000000
# algo-1-ch608_1  | average loss = 0.489842
# algo-1-ch608_1  | total feature number = 185
# algo-1-ch608_1  |
# algo-1-ch608_1  | INFO:root:Model learned using 93 training experiences.
# algo-1-ch608_1  | 2020-09-26 20:36:23,899 sagemaker-containers INFO     Reporting training SUCCESS
# tmpzqv1iuhr_algo-1-ch608_1 exited with code 0
# Aborting on container exit...
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpzqv1iuhr/algo-1-ch608 Please remove it manually.
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152579' with evaluation job id 'bandits-1601152346-model-id-1601152579-eval-1601152594'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmp410s9rgx/algo-1-h4ttf Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152579' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152579'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/eval' is 0.50855.
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152471' with evaluation job id 'bandits-1601152346-model-id-1601152471-eval-1601152609'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpw2ody5uh/algo-1-62gb6 Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152471' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152471'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152570/eval' is 0.755483.
# New bandit model evaluation score 0.755483
# Current bandit model evaluation score 0.50855
# Deploying new bandit model id bandits-1601152346-model-id-1601152579 in loop 1
# INFO:orchestrator:Model 'bandits-1601152346-model-id-1601152579' is ready to deploy.
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Found new model! Trying to replace Model ID: bandits-1601152346-model-id-1601152471 with Model ID: bandits-1601152346-model-id-1601152579
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [23] [INFO] Handling signal: hup
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [23] [INFO] Hang up: Master
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [52] [INFO] Booting worker with pid: 52
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [53] [INFO] Booting worker with pid: 53
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/UmqdVNIq/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152579
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [54] [INFO] Booting worker with pid: 54
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [38] [INFO] Worker exiting (pid: 38)
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/UmqdVNIq/vw.model']
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [40] [INFO] Worker exiting (pid: 40)
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152579
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [39] [INFO] Worker exiting (pid: 39)
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [55] [INFO] Booting worker with pid: 55
# algo-1-svi0d_1  | [2020-09-26 20:37:04 +0000] [41] [INFO] Worker exiting (pid: 41)
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/UmqdVNIq/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152579
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/UmqdVNIq/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152579
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:37:04 INFO 139633647494912] Started VW process!
#
#     ################################
#     # Incremental Training Loop 3
#     ################################
#
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-146478650644' for athena queries
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152645
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152645/train/local-joined-data-1601152646.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152645/eval/local-joined-data-1601152646.csv
# INFO:orchestrator:Use last trained model bandits-1601152346-model-id-1601152579 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601152346-model-id-1601152654''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpmwn24_2__algo-1-5tdf6_1 ...
# Attaching to tmpmwn24_2__algo-1-5tdf6_12mdone
# algo-1-5tdf6_1  | 2020-09-26 20:37:38,923 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5tdf6_1  | 2020-09-26 20:37:38,935 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5tdf6_1  | 2020-09-26 20:37:38,946 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5tdf6_1  | 2020-09-26 20:37:38,956 sagemaker-containers INFO     Invoking user script
# algo-1-5tdf6_1  |
# algo-1-5tdf6_1  | Training Env:
# algo-1-5tdf6_1  |
# algo-1-5tdf6_1  | {
# algo-1-5tdf6_1  |     "additional_framework_parameters": {
# algo-1-5tdf6_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-5tdf6_1  |     },
# algo-1-5tdf6_1  |     "channel_input_dirs": {
# algo-1-5tdf6_1  |         "training": "/opt/ml/input/data/training",
# algo-1-5tdf6_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-5tdf6_1  |     },
# algo-1-5tdf6_1  |     "current_host": "algo-1-5tdf6",
# algo-1-5tdf6_1  |     "framework_module": null,
# algo-1-5tdf6_1  |     "hosts": [
# algo-1-5tdf6_1  |         "algo-1-5tdf6"
# algo-1-5tdf6_1  |     ],
# algo-1-5tdf6_1  |     "hyperparameters": {
# algo-1-5tdf6_1  |         "exploration_policy": "cover",
# algo-1-5tdf6_1  |         "epsilon": 0.1,
# algo-1-5tdf6_1  |         "num_policies": 3,
# algo-1-5tdf6_1  |         "num_arms": 2,
# algo-1-5tdf6_1  |         "cfa_type": "dr"
# algo-1-5tdf6_1  |     },
# algo-1-5tdf6_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-5tdf6_1  |     "input_data_config": {
# algo-1-5tdf6_1  |         "training": {
# algo-1-5tdf6_1  |             "TrainingInputMode": "File"
# algo-1-5tdf6_1  |         },
# algo-1-5tdf6_1  |         "pretrained_model": {
# algo-1-5tdf6_1  |             "TrainingInputMode": "File",
# algo-1-5tdf6_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-5tdf6_1  |         }
# algo-1-5tdf6_1  |     },
# algo-1-5tdf6_1  |     "input_dir": "/opt/ml/input",
# algo-1-5tdf6_1  |     "is_master": true,
# algo-1-5tdf6_1  |     "job_name": "bandits-1601152346-model-id-1601152654",
# algo-1-5tdf6_1  |     "log_level": 20,
# algo-1-5tdf6_1  |     "master_hostname": "algo-1-5tdf6",
# algo-1-5tdf6_1  |     "model_dir": "/opt/ml/model",
# algo-1-5tdf6_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152654/source/sourcedir.tar.gz",
# algo-1-5tdf6_1  |     "module_name": "train-vw",
# algo-1-5tdf6_1  |     "network_interface_name": "eth0",
# algo-1-5tdf6_1  |     "num_cpus": 8,
# algo-1-5tdf6_1  |     "num_gpus": 0,
# algo-1-5tdf6_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-5tdf6_1  |     "output_dir": "/opt/ml/output",
# algo-1-5tdf6_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-5tdf6_1  |     "resource_config": {
# algo-1-5tdf6_1  |         "current_host": "algo-1-5tdf6",
# algo-1-5tdf6_1  |         "hosts": [
# algo-1-5tdf6_1  |             "algo-1-5tdf6"
# algo-1-5tdf6_1  |         ]
# algo-1-5tdf6_1  |     },
# algo-1-5tdf6_1  |     "user_entry_point": "train-vw.py"
# algo-1-5tdf6_1  | }
# algo-1-5tdf6_1  |
# algo-1-5tdf6_1  | Environment variables:
# algo-1-5tdf6_1  |
# algo-1-5tdf6_1  | SM_HOSTS=["algo-1-5tdf6"]
# algo-1-5tdf6_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-5tdf6_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-5tdf6_1  | SM_USER_ENTRY_POINT=train-vw.py
# ...
# Predicted Class from Model 1: 1, Actual Class: 1
# INFO:orchestrator:Successfully create S3 bucket 'sagemaker-us-east-1-146478650644' for athena queries
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/train/local-joined-data-1601152797.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/eval/local-joined-data-1601152797.csv
# INFO:orchestrator:Use last trained model bandits-1601152346-model-id-1601152729 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601152346-model-id-1601152805''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpiy75374g_algo-1-zwwjx_1 ...
# Attaching to tmpiy75374g_algo-1-zwwjx_12mdone
# algo-1-zwwjx_1  | 2020-09-26 20:40:11,556 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-zwwjx_1  | 2020-09-26 20:40:11,568 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-zwwjx_1  | 2020-09-26 20:40:11,579 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-zwwjx_1  | 2020-09-26 20:40:11,589 sagemaker-containers INFO     Invoking user script
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | Training Env:
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | {
# algo-1-zwwjx_1  |     "additional_framework_parameters": {
# algo-1-zwwjx_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-zwwjx_1  |     },
# algo-1-zwwjx_1  |     "channel_input_dirs": {
# algo-1-zwwjx_1  |         "training": "/opt/ml/input/data/training",
# algo-1-zwwjx_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-zwwjx_1  |     },
# algo-1-zwwjx_1  |     "current_host": "algo-1-zwwjx",
# algo-1-zwwjx_1  |     "framework_module": null,
# algo-1-zwwjx_1  |     "hosts": [
# algo-1-zwwjx_1  |         "algo-1-zwwjx"
# algo-1-zwwjx_1  |     ],
# algo-1-zwwjx_1  |     "hyperparameters": {
# algo-1-zwwjx_1  |         "exploration_policy": "cover",
# algo-1-zwwjx_1  |         "epsilon": 0.1,
# algo-1-zwwjx_1  |         "num_policies": 3,
# algo-1-zwwjx_1  |         "num_arms": 2,
# algo-1-zwwjx_1  |         "cfa_type": "dr"
# algo-1-zwwjx_1  |     },
# algo-1-zwwjx_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-zwwjx_1  |     "input_data_config": {
# algo-1-zwwjx_1  |         "training": {
# algo-1-zwwjx_1  |             "TrainingInputMode": "File"
# algo-1-zwwjx_1  |         },
# algo-1-zwwjx_1  |         "pretrained_model": {
# algo-1-zwwjx_1  |             "TrainingInputMode": "File",
# algo-1-zwwjx_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-zwwjx_1  |         }
# algo-1-zwwjx_1  |     },
# algo-1-zwwjx_1  |     "input_dir": "/opt/ml/input",
# algo-1-zwwjx_1  |     "is_master": true,
# algo-1-zwwjx_1  |     "job_name": "bandits-1601152346-model-id-1601152805",
# algo-1-zwwjx_1  |     "log_level": 20,
# algo-1-zwwjx_1  |     "master_hostname": "algo-1-zwwjx",
# algo-1-zwwjx_1  |     "model_dir": "/opt/ml/model",
# algo-1-zwwjx_1  |     "module_dir": "s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152805/source/sourcedir.tar.gz",
# algo-1-zwwjx_1  |     "module_name": "train-vw",
# algo-1-zwwjx_1  |     "network_interface_name": "eth0",
# algo-1-zwwjx_1  |     "num_cpus": 8,
# algo-1-zwwjx_1  |     "num_gpus": 0,
# algo-1-zwwjx_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-zwwjx_1  |     "output_dir": "/opt/ml/output",
# algo-1-zwwjx_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-zwwjx_1  |     "resource_config": {
# algo-1-zwwjx_1  |         "current_host": "algo-1-zwwjx",
# algo-1-zwwjx_1  |         "hosts": [
# algo-1-zwwjx_1  |             "algo-1-zwwjx"
# algo-1-zwwjx_1  |         ]
# algo-1-zwwjx_1  |     },
# algo-1-zwwjx_1  |     "user_entry_point": "train-vw.py"
# algo-1-zwwjx_1  | }
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | Environment variables:
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | SM_HOSTS=["algo-1-zwwjx"]
# algo-1-zwwjx_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-zwwjx_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-zwwjx_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-zwwjx_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-zwwjx_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-zwwjx","hosts":["algo-1-zwwjx"]}
# algo-1-zwwjx_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-zwwjx_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-zwwjx_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-zwwjx_1  | SM_CURRENT_HOST=algo-1-zwwjx
# algo-1-zwwjx_1  | SM_MODULE_NAME=train-vw
# algo-1-zwwjx_1  | SM_LOG_LEVEL=20
# algo-1-zwwjx_1  | SM_FRAMEWORK_MODULE=
# algo-1-zwwjx_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-zwwjx_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-zwwjx_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-zwwjx_1  | SM_NUM_CPUS=8
# algo-1-zwwjx_1  | SM_NUM_GPUS=0
# algo-1-zwwjx_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-zwwjx_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152805/source/sourcedir.tar.gz
# algo-1-zwwjx_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-zwwjx","framework_module":null,"hosts":["algo-1-zwwjx"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601152346-model-id-1601152805","log_level":20,"master_hostname":"algo-1-zwwjx","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-146478650644/bandits-1601152346/training_jobs/bandits-1601152346-model-id-1601152805/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-zwwjx","hosts":["algo-1-zwwjx"]},"user_entry_point":"train-vw.py"}
# algo-1-zwwjx_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-zwwjx_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-zwwjx_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-zwwjx_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-zwwjx_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-zwwjx_1  | SM_HP_EPSILON=0.1
# algo-1-zwwjx_1  | SM_HP_NUM_POLICIES=3
# algo-1-zwwjx_1  | SM_HP_NUM_ARMS=2
# algo-1-zwwjx_1  | SM_HP_CFA_TYPE=dr
# algo-1-zwwjx_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | Invoking script with the following command:
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-zwwjx_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-zwwjx_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-zwwjx_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-zwwjx_1  | INFO:VW CLI:successfully created VWModel
# algo-1-zwwjx_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-zwwjx_1  | INFO:VW CLI:Started VW process!
# algo-1-zwwjx_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152797.csv')]
# algo-1-zwwjx_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-zwwjx_1  | predictions = /dev/stdout
# algo-1-zwwjx_1  | Num weight bits = 18
# algo-1-zwwjx_1  | learning rate = 0.5
# algo-1-zwwjx_1  | initial_t = 0
# algo-1-zwwjx_1  | power_t = 0.5
# algo-1-zwwjx_1  | using no cache
# algo-1-zwwjx_1  | Reading datafile =
# algo-1-zwwjx_1  | num sources = 1
# algo-1-zwwjx_1  | average  since         example        example  current  current  current
# algo-1-zwwjx_1  | loss     last          counter         weight    label  predict features
# algo-1-zwwjx_1  | 0.000000 0.000000            1            1.0        1 1:1.000000        2
# algo-1-zwwjx_1  | 0.501477 1.002955            2            2.0        1 1:0.500000        2
# algo-1-zwwjx_1  | 0.329928 0.158379            4            4.0        1 1:0.591752        2
# algo-1-zwwjx_1  | 0.554861 0.779795            8            8.0        2 2:0.666667        2
# algo-1-zwwjx_1  | 0.599225 0.643589           16           16.0        1 1:0.666667        2
# algo-1-zwwjx_1  | 0.583100 0.566975           32           32.0        1 1:1.000000        2
# algo-1-zwwjx_1  | 0.542001 0.500901           64           64.0        1 2:1.000000        2
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | finished run
# algo-1-zwwjx_1  | number of examples = 96
# algo-1-zwwjx_1  | weighted example sum = 96.000000
# algo-1-zwwjx_1  | weighted label sum = 0.000000
# algo-1-zwwjx_1  | average loss = 0.522596
# algo-1-zwwjx_1  | total feature number = 192
# algo-1-zwwjx_1  |
# algo-1-zwwjx_1  | INFO:root:Model learned using 96 training experiences.
# algo-1-zwwjx_1  | 2020-09-26 20:40:12,036 sagemaker-containers INFO     Reporting training SUCCESS
# tmpiy75374g_algo-1-zwwjx_1 exited with code 0
# Aborting on container exit...
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpiy75374g/algo-1-zwwjx Please remove it manually.
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152805' with evaluation job id 'bandits-1601152346-model-id-1601152805-eval-1601152822'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmp3dzspsn7/algo-1-j5vyz Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152805' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152805'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/eval' is 0.25.
# INFO:orchestrator:Evaluating model 'bandits-1601152346-model-id-1601152729' with evaluation job id 'bandits-1601152346-model-id-1601152729-eval-1601152837'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmp7xj7zupt/algo-1-lg0xy Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601152346-model-id-1601152729' on eval data set 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601152346-model-id-1601152729'with data 's3://sagemaker-us-east-1-146478650644/bandits-1601152346/joined_data/bandits-1601152346-join-job-id-1601152796/eval' is 0.5.
# New bandit model evaluation score 0.5
# Current bandit model evaluation score 0.25
# Deploying new bandit model id bandits-1601152346-model-id-1601152805 in loop 4
# INFO:orchestrator:Model 'bandits-1601152346-model-id-1601152805' is ready to deploy.
# algo-1-svi0d_1  | [09/26/2020 20:40:52 INFO 139633647494912] Found new model! Trying to replace Model ID: bandits-1601152346-model-id-1601152729 with Model ID: bandits-1601152346-model-id-1601152805
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [23] [INFO] Handling signal: hup
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [23] [INFO] Hang up: Master
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [94] [INFO] Booting worker with pid: 94
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [95] [INFO] Booting worker with pid: 95
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/re6UflyP/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152805
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [96] [INFO] Booting worker with pid: 96
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [80] [INFO] Worker exiting (pid: 80)
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [81] [INFO] Worker exiting (pid: 81)
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [83] [INFO] Worker exiting (pid: 83)
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [82] [INFO] Worker exiting (pid: 82)
# algo-1-svi0d_1  | [2020-09-26 20:40:53 +0000] [97] [INFO] Booting worker with pid: 97
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/re6UflyP/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152805
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/re6UflyP/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152805
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] creating an instance of VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] successfully created VWModel
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/re6UflyP/vw.model']
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Loaded weights successfully for Model ID:bandits-1601152346-model-id-1601152805
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Started VW process!
# algo-1-svi0d_1  | [09/26/2020 20:40:53 INFO 139633647494912] Started VW process!
# Total time taken to complete 5 loops: 366.34105348587036

# %% [markdown]
# # _Ignore Any Errors ^^ Above ^^_

# %% [markdown]
# # Check Experiment State:  EVALUATED
#
# `evaluation_state`: `EVALUATED`
#
# The same bandit_model_id will appear in both `last_trained_model_id` and `last_evaluation_job_id` fields below.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152805',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152805',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601152346-join-job-id-1601152796',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601152346-model-id-1601152729-eval-1601152837',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Check Experiment Status:  JOINED
# `joining_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152805',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152805',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601152346-join-job-id-1601152796',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601152346-model-id-1601152729-eval-1601152837',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Check Experiment Status:  DEPLOYED
# `deploying_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601152346',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601152346-model-id-1601152805',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601152346-model-id-1601152805',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601152346-join-job-id-1601152796',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601152346-model-id-1601152729-eval-1601152837',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Copy All Joined Event and Reward Data from S3 to Local Notebook

# %%
from sagemaker.s3 import S3Downloader

all_joined_data_s3_uri_list = all_joined_train_data_s3_uri_list + all_joined_eval_data_s3_uri_list

df_list = []

for joined_data_s3_prefix_uri in all_joined_data_s3_uri_list:
    joined_data_s3_uri_file_path = './'

    joined_data_s3_uri = S3Downloader.list(joined_data_s3_prefix_uri)[0]    
    S3Downloader.download(joined_data_s3_uri, joined_data_s3_uri_file_path)
    joined_data_local_file_path = joined_data_s3_uri.split('/')[-1]

    df = pd.read_csv(joined_data_local_file_path, 
                     delimiter=',', 
                     quoting=csv.QUOTE_ALL)
    
    df_list.append(df)

# %%
all_joined_data_df = pd.concat(df_list, ignore_index=True)
all_joined_data_df.tail(10)
# Out:
#      reward                                 event_id  action  action_prob  \
# 590       1   81568878396915597482881481068357222402       1          1.0
# 591       1   83313499965675451337727048771012001794       1          1.0
# 592       0   85346138881341785193501591524296753154       1          1.0
# 593       1   86677238563237938045322586965306114050       1          1.0
# 594       1   87185907927309894514617793125087838210       1          1.0
# 595       0   88801880390342336220484256695479042050       1          1.0
# 596       1  139323799541392240813622422772743536642       1          1.0
# 597       1  140302798177132250953964567303860387842       1          1.0
# 598       0  143276407795094998349671249015135666178       1          1.0
# 599       0  143844224151610353719877959833277825026       1          1.0
#
#                                    model_id observation  sample_prob
# 590  bandits-1601152346-model-id-1601152654        [49]     0.983763
# 591  bandits-1601152346-model-id-1601152654        [59]     0.996797
# 592  bandits-1601152346-model-id-1601152654        [19]     0.907469
# 593  bandits-1601152346-model-id-1601152654        [10]     0.961745
# 594  bandits-1601152346-model-id-1601152654        [86]     0.935049
# 595  bandits-1601152346-model-id-1601152654        [99]     0.973590
# 596  bandits-1601152346-model-id-1601152729        [84]     0.975067
# 597  bandits-1601152346-model-id-1601152729        [78]     0.908955
# 598  bandits-1601152346-model-id-1601152729        [99]     0.943582
# 599  bandits-1601152346-model-id-1601152729        [96]     0.990095

# %% [markdown]
# # Review Invocations of BERT Model 1 and 2

# %%
print('Total Invocations of BERT Model 1:  {}'.format(client_app.action_count[1]))
print('Total Invocations of BERT Model 2:  {}'.format(client_app.action_count[2]))
# Out:
# Total Invocations of BERT Model 1:  482
# Total Invocations of BERT Model 2:  118

# %%
from datetime import datetime, timedelta

import boto3
import pandas as pd

cw = boto3.Session().client(service_name='cloudwatch', region_name=region)

def get_invocation_metrics_for_endpoint_variant(endpoint_name,
                                                namespace_name,
                                                metric_name,
                                                variant_name,
                                                start_time,
                                                end_time):
    metrics = cw.get_metric_statistics(
        Namespace=namespace_name,
        MetricName=metric_name,
        StartTime=start_time,
        EndTime=end_time,
        Period=60,
        Statistics=["Sum"],
        Dimensions=[
            {
                "Name": "EndpointName",
                "Value": endpoint_name
            },
            {
                "Name": "VariantName",
                "Value": variant_name
            }
        ]
    )

    if metrics['Datapoints']:
        return pd.DataFrame(metrics["Datapoints"])\
                .sort_values("Timestamp")\
                .set_index("Timestamp")\
                .drop("Unit", axis=1)\
                .rename(columns={"Sum": variant_name})
    else:
        return pd.DataFrame()

# %% [markdown]
# # Gather BERT Model 1 Invocations Metrics
# _Please be patient.  This will take 1-2 minutes._

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

time.sleep(75)

start_time = start_time or datetime.now() - timedelta(minutes=60)
end_time = datetime.now()
        
model_1_endpoint_invocations = get_invocation_metrics_for_endpoint_variant(
                                    endpoint_name=model_1_endpoint_name,
                                    namespace_name='AWS/SageMaker',                                   
                                    metric_name='Invocations',
                                    variant_name='AllTraffic',
                                    start_time=start_time, 
                                    end_time=end_time)

model_1_endpoint_invocations
# Out:
#                            AllTraffic
# Timestamp
# 2020-09-26 20:34:00+00:00       133.0
# 2020-09-26 20:35:00+00:00        36.0
# 2020-09-26 20:36:00+00:00        32.0
# 2020-09-26 20:37:00+00:00       100.0
# 2020-09-26 20:38:00+00:00        99.0
# 2020-09-26 20:39:00+00:00        82.0

# %% [markdown]
# # Gather BERT Model 2 Invocations Metrics
# _Please be patient.  This will take 1-2 minutes._

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

time.sleep(75)

start_time = start_time or datetime.now() - timedelta(minutes=60)
end_time = datetime.now()
        
model_2_endpoint_invocations = get_invocation_metrics_for_endpoint_variant(
                                    endpoint_name=model_2_endpoint_name,
                                    namespace_name='AWS/SageMaker',                                   
                                    metric_name='Invocations',
                                    variant_name='AllTraffic',
                                    start_time=start_time, 
                                    end_time=end_time)

model_2_endpoint_invocations
# Out:
#                            AllTraffic
# Timestamp
# 2020-09-26 20:34:00+00:00        24.0
# 2020-09-26 20:35:00+00:00        28.0
# 2020-09-26 20:36:00+00:00        47.0
# 2020-09-26 20:38:00+00:00         1.0
# 2020-09-26 20:39:00+00:00        18.0

# %%
rcParams['figure.figsize'] = 15, 10

x1 = range(0, model_1_endpoint_invocations.size)
y1 = model_1_endpoint_invocations['AllTraffic']
plt.plot(x1, y1, label="BERT Model 1")

x1 = range(0, model_2_endpoint_invocations.size)
y1 = model_2_endpoint_invocations['AllTraffic']
plt.plot(x1, y1, label="BERT Model 2")

plt.legend(loc=0, prop={'size': 20})
plt.xlabel('Time (Minutes)')
plt.ylabel('Number of Invocations')
# Out:
# Text(0, 0.5, 'Number of Invocations')

# %% [markdown]
# # Check the Invocation Metrics for the BERT Models

# %%
from IPython.core.display import display, HTML
    
display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region={}#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search={}">Model 1 SageMaker REST Endpoint</a></b>'.format(region, model_1_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search=tensorflow-training-2020-09-26-18-45-37-202-tf-1601151660">Model 1 SageMaker REST Endpoint</a></b>

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region={}#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search={}">Model 2 SageMaker REST Endpoint</a></b>'.format(region, model_2_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region=us-east-1#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search=tensorflow-training-2020-09-26-18-45-37-202-pt-1601151634">Model 2 SageMaker REST Endpoint</a></b>

# %% [markdown]
# # Visualize Bandit Action Probabilities
# This is the probability that the bandit model will choose a particular BERT model (action).

# %%
rcParams['figure.figsize'] = 15, 10

x1 = all_joined_data_df.query('action==1').index
y1 = all_joined_data_df.query('action==1').action_prob
plt.scatter(x1, y1, label="BERT Model 1")

x2 = all_joined_data_df.query('action==2').index
y2 = all_joined_data_df.query('action==2').action_prob
plt.scatter(x2, y2, label="BERT Model 2")

plt.legend(loc=3, prop={'size': 20})
plt.xlabel('Bandit Model Training Instances')
plt.ylabel('Action Probability')
# Out:
# Text(0, 0.5, 'Action Probability')

# %%
print('Mean action probability for BERT Model 1: {}'.format(all_joined_data_df.query('action==1')['action_prob'].mean()))
# Out:
# Mean action probability for BERT Model 1: 0.8277588609958517

# %%
print('Mean action probability for BERT Model 2: {}'.format(all_joined_data_df.query('action==2')['action_prob'].mean()))
# Out:
# Mean action probability for BERT Model 2: 0.6271188728813549

# %% [markdown]
# # Visualize Bandit Sample Probabilities
# Despite the action probability, we sample from all actions (BERT models).  Below is the sample probability for the chosen BERT model.

# %%
rcParams['figure.figsize'] = 15, 10

x1 = all_joined_data_df.query('action==1').index
y1 = all_joined_data_df.query('action==1').sample_prob
plt.scatter(x1, y1, label="BERT Model 1")

x2 = all_joined_data_df.query('action==2').index
y2 = all_joined_data_df.query('action==2').sample_prob
plt.scatter(x2, y2, label="BERT Model 2")

plt.legend(loc=0, prop={'size': 20})
plt.xlabel('Bandit Model Training Instances')
plt.ylabel('Sample Probability')
# Out:
# Text(0, 0.5, 'Sample Probability')

# %%
print('Mean sample probability for BERT Model 1: {}'.format(all_joined_data_df.query('action==1')['sample_prob'].mean()))
# Out:
# Mean sample probability for BERT Model 1: 0.49243565720037263

# %%
print('Mean sample probability for BERT Model 2: {}'.format(all_joined_data_df.query('action==2')['sample_prob'].mean()))
# Out:
# Mean sample probability for BERT Model 2: 0.4511294275382854

# %% [markdown]
# # Visualize Bandit Rewards

# %% [markdown]
# You can visualize the bandit-model training performance by plotting the rolling mean reward across client interactions.
#
# Here rolling mean reward is calculated on the last `rolling_window` number of data instances, where each data instance corresponds to a single client interaction.

# %%
rolling_window = 100

rcParams['figure.figsize'] = 15, 10
lwd = 5
cmap = plt.get_cmap('tab20')
colors=plt.cm.tab20(np.linspace(0, 1, 20))

rewards_df = pd.DataFrame(rewards_list, columns=['bandit']).rolling(rolling_window).mean()
rewards_df['perfect'] = sum(client_app.optimal_rewards) / len(client_app.optimal_rewards)

rewards_df.tail(10)
# Out:
#      bandit  perfect
# 490    0.44      1.0
# 491    0.44      1.0
# 492    0.44      1.0
# 493    0.43      1.0
# 494    0.43      1.0
# 495    0.43      1.0
# 496    0.42      1.0
# 497    0.41      1.0
# 498    0.41      1.0
# 499    0.42      1.0

# %%
rewards_df.plot(y=['bandit', 'perfect'], 
                linewidth=lwd)
plt.legend(loc=4, prop={'size': 20})
plt.tick_params(axis='both', which='major', labelsize=15)
plt.yticks([0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 1.00])
plt.xticks([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])

plt.xlabel('Training Instances (Model is Updated Every %s Instances)' % retrain_batch_size, size=20)
plt.ylabel('Rolling {} Mean Reward'.format(rolling_window), size=30)
plt.grid()
plt.show()

# %%
rewards_df['bandit'].mean()
# Out:
# 0.4725935162094764

# %% [markdown]
# # Monitor the Bandit Model in CloudWatch

# %%
from markdown_helper import *
from IPython.display import Markdown

display(Markdown(bandit_experiment_manager.get_cloudwatch_dashboard_details()))
# Out:
# You can monitor your Training/Hosting evaluation metrics on this [CloudWatch Dashboard](https://us-east-1.console.aws.amazon.com/cloudwatch/home?region=us-east-1#dashboards:name=bandits-1601152346;start=PT1H)
#
# (Note: This would need Trained/Hosted Models to be evaluated in order to publish Evaluation Scores)

# %% [markdown]
# # Review the DynamoDB Tables and S3 Data

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/dynamodb/home?region={}#tables:selected=BanditsExperimentTable;tab=items">Bandits Experiment DynamoDB Table</a></b>'.format(region)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/dynamodb/home?region=us-east-1#tables:selected=BanditsExperimentTable;tab=items">Bandits Experiment DynamoDB Table</a></b>

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/{}/{}/?region={}&tab=overview">Bandits Experiment S3 Data</a></b>'.format(bucket, bandit_experiment_manager.experiment_id, region)))
# Out:
# <b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-146478650644/bandits-1601152346/?region=us-east-1&tab=overview">Bandits Experiment S3 Data</a></b>

# %% [markdown]
# # Clean Up

# %% [markdown]
# We have three DynamoDB tables from the bandits application above.  To better maintain them, we should remove the related records if the experiment has finished.
#
# Only execute the clean up cells below when you've finished the current experiment and want to deprecate everything associated with it.
#
# _The CloudWatch metrics will be removed during this cleanup step._

# %%
print('Cleaning up experiment_id {}'.format(bandit_experiment_manager.experiment_id))
try:
    bandit_experiment_manager.clean_resource(experiment_id=bandit_experiment_manager.experiment_id)
    bandit_experiment_manager.clean_table_records(experiment_id=bandit_experiment_manager.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# INFO:orchestrator:Deleting hosting endpoint 'bandits-1601152346'...
# Cleaning up experiment_id bandits-1601152346
# WARNING:orchestrator.clients.ddb.join_db_client:Deleting join job records of experiment...
# WARNING:orchestrator.clients.ddb.model_db_client:Deleting model records of experiment...
# WARNING:orchestrator.clients.ddb.experiment_db_client:Deleting experiment record...
# Gracefully stopping... (press Ctrl+C again to force)
